# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("http://quotes.toscrape.com/")
c= r.content

# %%
type(c)
# Out:
# bytes

# %%
c
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cIt is our choices, Harry, that show what we truly are, far more than our abilities.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThere are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" conten ...

# %%
soup = BeautifulSoup(c,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#        <a class="tag" href="/tag/change/page/1/">
#         change
#        </a>
#        <a class="tag" href="/tag/deep-thoughts/page/1/">
#         deep-thoughts
#        </a>
#        <a class="tag" href="/tag/thinking/page/1/">
#         thinking
#        </a>
#        <a class="tag" href="/tag/world/page/1/">
#         world
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “It is our choices, Harry, that show what we truly are, far more than our abilities.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         J.K. Rowling
#        </small>
#        <a href="/author/J-K-Rowling">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
#        <a class="tag" href="/tag/abilities/page/1/">
#         abilities
#        </a>
#        <a class="tag" href="/tag/choices/page/1/">
#         choices
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#        <a class="tag" href="/tag/life/page/1/">
#         life
#        </a>
#        <a class="tag" href="/tag/live/page/1/">
#         live
#        </a>
#        <a class="tag" href="/tag/miracle/page/1/">
#         miracle
#        </a>
#        <a class="tag" href="/tag/miracles/page/1/">
#         miracles
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Jane Austen
#        </small>
#        <a href="/author/Jane-Austen">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="aliteracy,books,classic,humor" itemprop="keywords"/>
#        <a class="tag" href="/tag/aliteracy/page/1/">
#         aliteracy
#        </a>
#        <a class="tag" href="/tag/books/page/1/">
#         books
#        </a>
#        <a class="tag" href="/tag/classic/page/1/">
#         classic
#        </a>
#        <a class="tag" href="/tag/humor/page/1/">
#         humor
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Marilyn Monroe
#        </small>
#        <a href="/author/Marilyn-Monroe">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="be-yourself,inspirational" itemprop="keywords"/>
#        <a class="tag" href="/tag/be-yourself/page/1/">
#         be-yourself
#        </a>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “Try not to become a man of success. Rather become a man of value.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="adulthood,success,value" itemprop="keywords"/>
#        <a class="tag" href="/tag/adulthood/page/1/">
#         adulthood
#        </a>
#        <a class="tag" href="/tag/success/page/1/">
#         success
#        </a>
#        <a class="tag" href="/tag/value/page/1/">
#         value
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “It is better to be hated for what you are than to be loved for what you are not.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         André Gide
#        </small>
#        <a href="/author/Andre-Gide">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="life,love" itemprop="keywords"/>
#        <a class="tag" href="/tag/life/page/1/">
#         life
#        </a>
#        <a class="tag" href="/tag/love/page/1/">
#         love
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “I have not failed. I've just found 10,000 ways that won't work.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Thomas A. Edison
#        </small>
#        <a href="/author/Thomas-A-Edison">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="edison,failure,inspirational,paraphrased" itemprop="keywords"/>
#        <a class="tag" href="/tag/edison/page/1/">
#         edison
#        </a>
#        <a class="tag" href="/tag/failure/page/1/">
#         failure
#        </a>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#        <a class="tag" href="/tag/paraphrased/page/1/">
#         paraphrased
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Eleanor Roosevelt
#        </small>
#        <a href="/author/Eleanor-Roosevelt">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="misattributed-eleanor-roosevelt" itemprop="keywords"/>
#        <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">
#         misattributed-eleanor-roosevelt
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “A day without sunshine is like, you know, night.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Steve Martin
#        </small>
#        <a href="/author/Steve-Martin">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
#        <a class="tag" href="/tag/humor/page/1/">
#         humor
#        </a>
#        <a class="tag" href="/tag/obvious/page/1/">
#         obvious
#        </a>
#        <a class="tag" href="/tag/simile/page/1/">
#         simile
#        </a>
#       </div>
#      </div>
#      <nav>
#       <ul class="pager">
#        <li class="next">
#         <a href="/page/2/">
#          Next
#          <span aria-hidden="true">
#           →
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div class="col-md-4 tags-box">
#      <h2>
#       Top Ten tags
#      </h2>
#      <span class="tag-item">
#       <a class="tag" href="/tag/love/" style="font-size: 28px">
#        love
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/inspirational/" style="font-size: 26px">
#        inspirational
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/life/" style="font-size: 26px">
#        life
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/humor/" style="font-size: 24px">
#        humor
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/books/" style="font-size: 22px">
#        books
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/reading/" style="font-size: 14px">
#        reading
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/friendship/" style="font-size: 10px">
#        friendship
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/friends/" style="font-size: 8px">
#        friends
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/truth/" style="font-size: 8px">
#        truth
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/simile/" style="font-size: 6px">
#        simile
#       </a>
#      </span>
#     </div>
#    </div>
#   </div>
#   <footer class="footer">
#    <div class="container">
#     <p class="text-muted">
#      Quotes by:
#      <a href="https://www.goodreads.com/quotes">
#       GoodReads.com
#      </a>
#     </p>
#     <p class="copyright">
#      Made with
#      <span class="sh-red">
#       ❤
#      </span>
#      by
#      <a href="https://scrapinghub.com">
#       Scrapinghub
#      </a>
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %%
all = soup.find_all("div",{"class":"col-md-8"})

# %%
all
# Out:
# [<div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>,
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
#  <span>by <small class="author" itemprop="author">J.K. Rowling</small>
#  <a href="/author/J-K-Rowling">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>
#  <a class="tag" href="/tag/choices/page/1/">choices</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  <a class="tag" href="/tag/life/page/1/">life</a>
#  <a class="tag" href="/tag/live/page/1/">live</a>
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>
#  <span>by <small class="author" itemprop="author">Jane Austen</small>
#  <a href="/author/Jane-Austen">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="aliteracy,books,classic,humor" itemprop="keywords"/>
#  <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>
#  <a class="tag" href="/tag/books/page/1/">books</a>
#  <a class="tag" href="/tag/classic/page/1/">classic</a>
#  <a class="tag" href="/tag/humor/page/1/">humor</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>
#  <span>by <small class="author" itemprop="author">Marilyn Monroe</small>
#  <a href="/author/Marilyn-Monroe">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="be-yourself,inspirational" itemprop="keywords"/>
#  <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="adulthood,success,value" itemprop="keywords"/>
#  <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>
#  <a class="tag" href="/tag/success/page/1/">success</a>
#  <a class="tag" href="/tag/value/page/1/">value</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>
#  <span>by <small class="author" itemprop="author">André Gide</small>
#  <a href="/author/Andre-Gide">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="life,love" itemprop="keywords"/>
#  <a class="tag" href="/tag/life/page/1/">life</a>
#  <a class="tag" href="/tag/love/page/1/">love</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“I have not failed. I've just found 10,000 ways that won't work.”</span>
#  <span>by <small class="author" itemprop="author">Thomas A. Edison</small>
#  <a href="/author/Thomas-A-Edison">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="edison,failure,inspirational,paraphrased" itemprop="keywords"/>
#  <a class="tag" href="/tag/edison/page/1/">edison</a>
#  <a class="tag" href="/tag/failure/page/1/">failure</a>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it's in hot water.”</span>
#  <span>by <small class="author" itemprop="author">Eleanor Roosevelt</small>
#  <a href="/author/Eleanor-Roosevelt">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="misattributed-eleanor-roosevelt" itemprop="keywords"/>
#  <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>
#  </div>
#  </div>
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
#  <span>by <small class="author" itemprop="author">Steve Martin</small>
#  <a href="/author/Steve-Martin">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
#  <a class="tag" href="/tag/humor/page/1/">humor</a>
#  <a class="tag" href="/tag/obvious/page/1/">obvious</a>
#  <a class="tag" href="/tag/simile/page/1/">simile</a>
#  </div>
#  </div>
#  <nav>
#  <ul class="pager">
#  <li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>
#  </ul>
#  </nav>
#  </div>]

# %%
find1 = soup.find_all("div",{"class":"quote"})

# %%
find1
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
#  <span>by <small class="author" itemprop="author">J.K. Rowling</small>
#  <a href="/author/J-K-Rowling">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>
#  <a class="tag" href="/tag/choices/page/1/">choices</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  <a class="tag" href="/tag/life/page/1/">life</a>
#  <a class="tag" href="/tag/live/page/1/">live</a>
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>
#  <span>by <small class="author" itemprop="author">Jane Austen</small>
#  <a href="/author/Jane-Austen">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="aliteracy,books,classic,humor" itemprop="keywords"/>
#  <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>
#  <a class="tag" href="/tag/books/page/1/">books</a>
#  <a class="tag" href="/tag/classic/page/1/">classic</a>
#  <a class="tag" href="/tag/humor/page/1/">humor</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>
#  <span>by <small class="author" itemprop="author">Marilyn Monroe</small>
#  <a href="/author/Marilyn-Monroe">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="be-yourself,inspirational" itemprop="keywords"/>
#  <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="adulthood,success,value" itemprop="keywords"/>
#  <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>
#  <a class="tag" href="/tag/success/page/1/">success</a>
#  <a class="tag" href="/tag/value/page/1/">value</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>
#  <span>by <small class="author" itemprop="author">André Gide</small>
#  <a href="/author/Andre-Gide">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="life,love" itemprop="keywords"/>
#  <a class="tag" href="/tag/life/page/1/">life</a>
#  <a class="tag" href="/tag/love/page/1/">love</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“I have not failed. I've just found 10,000 ways that won't work.”</span>
#  <span>by <small class="author" itemprop="author">Thomas A. Edison</small>
#  <a href="/author/Thomas-A-Edison">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="edison,failure,inspirational,paraphrased" itemprop="keywords"/>
#  <a class="tag" href="/tag/edison/page/1/">edison</a>
#  <a class="tag" href="/tag/failure/page/1/">failure</a>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it's in hot water.”</span>
#  <span>by <small class="author" itemprop="author">Eleanor Roosevelt</small>
#  <a href="/author/Eleanor-Roosevelt">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="misattributed-eleanor-roosevelt" itemprop="keywords"/>
#  <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
#  <span>by <small class="author" itemprop="author">Steve Martin</small>
#  <a href="/author/Steve-Martin">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
#  <a class="tag" href="/tag/humor/page/1/">humor</a>
#  <a class="tag" href="/tag/obvious/page/1/">obvious</a>
#  <a class="tag" href="/tag/simile/page/1/">simile</a>
#  </div>
#  </div>]

# %%
span_tags=find1[0].find_all("span")

# %%
span_tags[0].text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
href_tags = h1_tags[0].find_all("a")

# %%
href_tags
# Out:
# [<a href="/" style="text-decoration: none">Quotes to Scrape</a>]

# %%
href_tags[0].text
# Out:
# 'Quotes to Scrape'

# %%
href_tags[0].text
# Out:
# 'Quotes to Scrape'

# %%
for item in find1:
    print(item.find_all("small")[0].text)
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %%
for item in find1:
    print(item.find_all("span")[0].text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %% [markdown]
# # Real estate scrapper

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})

# %%
c = r.content

# %%
c
# Out:
# b'<!DOCTYPE html>\n<!-- saved from url=(0110)http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS -->\n<html lang="en" style="margin: 0px;overflow:hidden"><script async="" src="./LCWYROCKSPRINGS1_files/beacon.js"></script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/Kernel.js?0.3685073930846756"></script><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\n\n<script type="text/javascript" src="./LCWYROCKSPRINGS1_files/analytics.js"></script>\n<script type="text/javascript">archive_analytics.values.server_name="wwwb-app17.us.archive.org";archive_analytics.values.server_ms=227;</script>\n<link type="text/css" rel="stylesheet" href="./LCWYROCKSPRINGS1_files/banner-styles.css">\n\n\n      <title>Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, WY</title>\n\n      <meta name="title" content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, WY">\n      <meta name="description" content="Search Rock Springs real estate property listings to find homes for sale in Rock Springs, WY. Browse houses for sale in Rock Springs today!">\n      <meta name="keywords" content="Rock Springs real estate, Rock Springs homes, Rock Springs homes for sale, Rock Springs properties, Rock Springs listings, Rock Springs houses for sale, WY real estate, WY homes, WY homes for sale, WY properties, WY listings, WY houses for sale">\n\n\n\n      <script>if(window.innerWidth && (innerWidth<769)){location.href+=(location.href.match("\\\\?"))?"&v=0":"?v=0";}</script>\n\n\n         <link rel="alternate" hreflang="en-US" href="http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/">\n\n\n         <link rel="alternate" hreflang="es" href="http://espanol.century21.com/propiedades-en-venta/rock-springs-wy/LCWYROCKSPRINGS/">\n\n\n\n\n\n               <link rel="canonical" href="http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/">\n\n\n\n\n         <link rel="publisher" href="https://plus.google.com/+Century21">\n\n      <meta http-equiv="X-UA-Compatible" content="IE=8, IE=9">\n\n         <link rel="stylesheet" href="./LCWYROCKSPRINGS1_files/advanceLiquidMapCSS.css">\n\n\n      <link rel="stylesheet" href="./LCWYROCKSPRINGS1_files/liquidmappingPhone.css" media="screen and (max-width: 767px)">\n\n      <script>\n\n\nwindow.m_aDeferredMethods = [];\nwindow.defer = function (fn) {\n   (window.m_aDeferredMethods) ? window.m_aDeferredMethods.push(fn) : fn();\n};\n\n\ndocument.domain=function(){var a=document.location.host.split(".");return a[a.length-2]+".com"}();\n\n\nwindow.websiteCode = \'RES\';\ndefer(function () { myc21.setFacebookAppId(\'113564428714357\') });\n\n\n   var _gaq = _gaq || [];\n\n   _gaq.push([\'_setAccount\', \'UA-7095058-1\']);\n   _gaq.push([\'_setDomainName\', \'.century21.com\']);\n   _gaq.push([\'_trackPageview\']);\n\n   (function() {\n      var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n      ga.src = (\'https:\' == document.location.protocol ? \'/web/20160127020422/https://ssl\' : \'/web/20160127020422/http://www\') + \'.google-analytics.com/ga.js\';\n      var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n   })();\n\n\n      </script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/files/foreground.js?0.912317186374344"></script>\n\n\n         <script src="./LCWYROCKSPRINGS1_files/defaultJS.js"></script>\n\n         <script src="./LCWYROCKSPRINGS1_files/raphael.js"></script>\n\n         <script src="./LCWYROCKSPRINGS1_files/ImageCache.js"></script>\n\n         <script src="./LCWYROCKSPRINGS1_files/mapcontrol.ashx"></script><script src="./LCWYROCKSPRINGS1_files/veapicore.js" type="text/javascript"></script>\n\n         <script src="./LCWYROCKSPRINGS1_files/advanceLiquidMapJS.js"></script><style>.VE_Pushpin_Popup{position: absolute; z-index: 1000; display: non ...

# %%
soup=BeautifulSoup(c,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0110)http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS -->
# <html lang="en" style="margin: 0px;overflow:hidden"><script async="" src="./LCWYROCKSPRINGS1_files/beacon.js"></script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/Kernel.js?0.3685073930846756"></script><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="./LCWYROCKSPRINGS1_files/analytics.js" type="text/javascript"></script>
# <script type="text/javascript">archive_analytics.values.server_name="wwwb-app17.us.archive.org";archive_analytics.values.server_ms=227;</script>
# <link href="./LCWYROCKSPRINGS1_files/banner-styles.css" rel="stylesheet" type="text/css"/>
# <title>Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, WY</title>
# <meta content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, WY" name="title"/>
# <meta content="Search Rock Springs real estate property listings to find homes for sale in Rock Springs, WY. Browse houses for sale in Rock Springs today!" name="description"/>
# <meta content="Rock Springs real estate, Rock Springs homes, Rock Springs homes for sale, Rock Springs properties, Rock Springs listings, Rock Springs houses for sale, WY real estate, WY homes, WY homes for sale, WY properties, WY listings, WY houses for sale" name="keywords"/>
# <script>if(window.innerWidth && (innerWidth<769)){location.href+=(location.href.match("\\?"))?"&v=0":"?v=0";}</script>
# <link href="http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/" hreflang="en-US" rel="alternate"/>
# <link href="http://espanol.century21.com/propiedades-en-venta/rock-springs-wy/LCWYROCKSPRINGS/" hreflang="es" rel="alternate"/>
# <link href="http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/" rel="canonical"/>
# <link href="https://plus.google.com/+Century21" rel="publisher"/>
# <meta content="IE=8, IE=9" http-equiv="X-UA-Compatible"/>
# <link href="./LCWYROCKSPRINGS1_files/advanceLiquidMapCSS.css" rel="stylesheet"/>
# <link href="./LCWYROCKSPRINGS1_files/liquidmappingPhone.css" media="screen and (max-width: 767px)" rel="stylesheet"/>
# <script>
#
#
# window.m_aDeferredMethods = [];
# window.defer = function (fn) {
#    (window.m_aDeferredMethods) ? window.m_aDeferredMethods.push(fn) : fn();
# };
#
#
# document.domain=function(){var a=document.location.host.split(".");return a[a.length-2]+".com"}();
#
#
# window.websiteCode = 'RES';
# defer(function () { myc21.setFacebookAppId('113564428714357') });
#
#
#    var _gaq = _gaq || [];
#
#    _gaq.push(['_setAccount', 'UA-7095058-1']);
#    _gaq.push(['_setDomainName', '.century21.com']);
#    _gaq.push(['_trackPageview']);
#
#    (function() {
#       var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#       ga.src = ('https:' == document.location.protocol ? '/web/20160127020422/https://ssl' : '/web/20160127020422/http://www') + '.google-analytics.com/ga.js';
#       var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#    })();
#
#
#       </script><script src="chrome-extension://pkljnnogdmlajgaoodihioopfdkpgjgg/files/foreground.js?0.912317186374344"></script>
# <script src="./LCWYROCKSPRINGS1_files/defaultJS.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/raphael.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/ImageCache.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/mapcontrol.ashx"></script><script src="./LCWYROCKSPRINGS1_files/veapicore.js" type="text/javascript"></script>
# <script src="./LCWYROCKSPRINGS1_files/advanceLiquidMapJS.js"></script><style>.VE_Pushpin_Popup{position: absolute; z-index: 1000; display: none;}</style>
# <script src="./LCWYROCKSPRINGS1_files/moreSearchOptions.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/surroundingAreasMapping.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/surroundingAreasMappingDefault.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/la.js"></script>
# <!--[if lt IE 9]>
#          <script src="/js/html5shiv.js"></script>
#          <script src="/js/respond-custom.js"></script>
#       <![endif]-->
# <!--[if lte IE 8]>
#          <link rel="stylesheet" href="/css/ie8fix.css">
#       <![endif]-->
# <!--[if lte IE 7]>
#          <link rel="stylesheet" href="/css/ie7fix.css">
#       <![endif]-->
# <!--[if gt IE 8]><!-->
# <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
# <link href="./LCWYROCKSPRINGS1_files/responsiveLiquidMap.css" rel="stylesheet"/>
# <script>var g_responsiveEnabled = true;</script>
# <!--<![endif]-->
# <script charset="utf-8" src="./LCWYROCKSPRINGS1_files/conversion_async.js" type="text/javascript"></script>
# <script src="./LCWYROCKSPRINGS1_files/veapiOverlayStyleV2.js" type="text/javascript"></script><link href="./LCWYROCKSPRINGS1_files/veapiOverlayStyleV2.css" rel="stylesheet" rev="stylesheet" type="text/css"/><style id="style-1-cropbar-clipper">/* Copyright 2014 Evernote Corporation. All rights reserved. */
# .en-markup-crop-options {
#     top: 18px !important;
#     left: 50% !important;
#     margin-left: -100px !important;
#     width: 200px !important;
#     border: 2px rgba(255,255,255,.38) solid !important;
#     border-radius: 4px !important;
# }
#
# .en-markup-crop-options div div:first-of-type {
#     margin-left: 0px !important;
# }
# </style></head>
# <body class="liquidLayout res" id="results"><div class="" id="wm-ipp" lang="en" style="display: block;">
# <div style="position:fixed;left:0;top:0;width:100%!important">
# <div id="wm-ipp-inside">
# <table style="width:100%;"><tbody><tr>
# <td id="wm-logo">
# <a href="http://web.archive.org/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="./LCWYROCKSPRINGS1_files/wayback-toolbar-logo.png" width="110"/></a>
# </td>
# <td class="c">
# <table style="margin:0 auto;"><tbody><tr>
# <td class="u" colspan="2">
# <form action="http://web.archive.org/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top"><input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS"/><input name="type" type="hidden" value="replay"/><input name="date" type="hidden" value="20160127020422"/><input type="submit" value="Go"/><span id="wm_tb_options" style="display:block;"></span></form>
# </td>
# <td class="n" rowspan="2">
# <table><tbody>
# <!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->
# <tr class="m">
# <td class="b" nowrap="nowrap">
# <a href="http://web.archive.org/web/20151108094700/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" title="8 Nov 2015">NOV</a>
# </td>
# <td class="c" id="displayMonthEl" title="You are here: 2:04:22 Jan 27, 2016">Jan</td>
# <td class="f" nowrap="nowrap">
#
# 		    Feb
#
#                 </td>
# </tr>
# <!-- NEXT/PREV CAPTURE NAV AND DAY OF MONTH INDICATOR -->
# <tr class="d">
# <td class="b" nowrap="nowrap">
# <a href="http://web.archive.org/web/20151108094700/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" title="9:47:00 Nov 8, 2015"><img alt="Previous capture" border="0" height="16" src="./LCWYROCKSPRINGS1_files/wm_tb_prv_on.png" width="14"/></a>
# </td>
# <td class="c" id="displayDayEl" style="width:34px;font-size:24px;" title="You are here: 2:04:22 Jan 27, 2016">27</td>
# <td class="f" nowrap="nowrap">
# <img alt="Next capture" border="0" height="16" src="./LCWYROCKSPRINGS1_files/wm_tb_nxt_off.png" width="14"/>
# </td>
# </tr>
# <!-- NEXT/PREV YEAR NAV AND YEAR INDICATOR -->
# <tr class="y">
# <td class="b" nowrap="nowrap">
# <a href="http://web.archive.org/web/20141017051315/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/" title="17 Oct 2014"><strong>2014</strong></a>
# </td>
# <td class="c" id="displayYearEl" title="You are here: 2:04:22 Jan 27, 2016">2016</td>
# <td class="f" nowrap="nowrap">
#
#                    2017
#
# 	       </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# <tr>
# <td class="s">
# <a class="t" href="http://web.archive.org/web/20160127020422*/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" title="See a list of every capture for this URL">12 captures</a>
# <div class="r" title="Timespan for captures of this URL">20 Nov 11 - 27 Jan 16</div>
# </td>
# <td class="k">
# <a href="http://web.archive.org/web/19970415000000/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" id="wm-graph-anchor">
# <div id="wm-ipp-sparkline" title="Explore captures for this URL">
# <img alt="sparklines" border="0" height="27" id="sparklineImgId" onmousemove="__wm.mv(event,this)" onmouseout="__wm.st(0)" onmouseover="__wm.st(1)" src="./LCWYROCKSPRINGS1_files/graph.jsp" width="525"/>
# <div class="yt" style="display: none; width: 25px; height: 27px; left: 25px;"></div><div class="mt" style="display: none; width: 2px; height: 27px; left: 32px;"></div></div>
# </a>
# </td>
# </tr></tbody></table>
# </td>
# <td class="r">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS#close" onclick="__wm.h();return false;" style="background-image:url(/static/images/toolbar/wm_tb_close.png);top:5px;" title="Close the toolbar">Close</a>
# <a href="http://faq.web.archive.org/" style="background-image:url(/static/images/toolbar/wm_tb_help.png);bottom:5px;" target="_BLANK" title="You have selected a link to a website that is not owned or maintained by Century21.com. Different terms of use and privacy policies will apply.">Help</a>
# </td>
# </tr></tbody></table>
# </div>
# </div>
# </div>
# <!-- BEGIN WAYBACK TOOLBAR INSERT -->
# <script src="./LCWYROCKSPRINGS1_files/disclaim-element.js" type="text/javascript"></script>
# <script src="./LCWYROCKSPRINGS1_files/graph-calc.js" type="text/javascript"></script>
# <script type="text/javascript">//<![CDATA[
# var __wm = (function(imgWidth,imgHeight,yearImgWidth,monthImgWidth){
# var wbPrefix = "/web/";
# var wbCurrentUrl = "http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS";
#
# var firstYear = 1996;
# var displayDay = "27";
# var displayMonth = "Jan";
# var displayYear = "2016";
# var prettyMonths = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"];
# var $D=document,$=function(n){return document.getElementById(n)};
# var trackerVal,curYear = -1,curMonth = -1;
# var yearTracker,monthTracker;
# function showTrackers(val) {
#   if (val===trackerVal) return;
#   var $ipp=$("wm-ipp");
#   var $y=$("displayYearEl"),$m=$("displayMonthEl"),$d=$("displayDayEl");
#   if (val) {
#     $ipp.className="hi";
#   } else {
#     $ipp.className="";
#     $y.innerHTML=displayYear;$m.innerHTML=displayMonth;$d.innerHTML=displayDay;
#   }
#   yearTracker.style.display=val?"inline":"none";
#   monthTracker.style.display=val?"inline":"none";
#   trackerVal = val;
# }
# function trackMouseMove(event,element) {
#   var eventX = getEventX(event);
#   var elementX = getElementX(element);
#   var xOff = Math.min(Math.max(0, eventX - elementX),imgWidth);
#   var monthOff = xOff % yearImgWidth;
#
#   var year = Math.floor(xOff / yearImgWidth);
#   var monthOfYear = Math.min(11,Math.floor(monthOff / monthImgWidth));
#   // 1 extra border pixel at the left edge of the year:
#   var month = (year * 12) + monthOfYear;
#   var day = monthOff % 2==1?15:1;
#   var dateString = zeroPad(year + firstYear) + zeroPad(monthOfYear+1,2) +
#     zeroPad(day,2) + "000000";
#
#   $("displayYearEl").innerHTML=year+firstYear;
#   $("displayMonthEl").innerHTML=prettyMonths[monthOfYear];
#   // looks too jarring when it changes..
#   //$("displayDayEl").innerHTML=zeroPad(day,2);
#   var url = wbPrefix + dateString + '/' +  wbCurrentUrl;
#   $("wm-graph-anchor").href=url;
#
#   if(curYear != year) {
#     var yrOff = year * yearImgWidth;
#     yearTracker.style.left = yrOff + "px";
#     curYear = year;
#   }
#   if(curMonth != month) {
#     var mtOff = year + (month * monthImgWidth) + 1;
#     monthTracker.style.left = mtOff + "px";
#     curMonth = month;
#   }
# }
# function hideToolbar() {
#   $("wm-ipp").style.display="none";
# }
# function bootstrap() {
#   var $spk=$("wm-ipp-sparkline");
#   yearTracker=$D.createElement('div');
#   yearTracker.className='yt';
#   with(yearTracker.style){
#     display='none';width=yearImgWidth+"px";height=imgHeight+"px";
#   }
#   monthTracker=$D.createElement('div');
#   monthTracker.className='mt';
#   with(monthTracker.style){
#     display='none';width=monthImgWidth+"px";height=imgHeight+"px";
#   }
#   $spk.appendChild(yearTracker);
#   $spk.appendChild(monthTracker);
#
#   var $ipp=$("wm-ipp");
#   $ipp&&disclaimElement($ipp);
# }
# return{st:showTrackers,mv:trackMouseMove,h:hideToolbar,bt:bootstrap};
# })(525, 27, 25, 2);//]]>
# </script>
# <style type="text/css">
# body {
#   margin-top:0 !important;
#   padding-top:0 !important;
#   min-width:800px !important;
# }
# </style>
# <script type="text/javascript">__wm.bt();</script>
# <!-- END WAYBACK TOOLBAR INSERT -->
# <script>
#          var _comscore = _comscore || [];
#          _comscore.push({ c1: "2", c2: "7705242" });
#          (function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             s.src = (document.location.protocol == "https:" ? "/web/20160127020422/https://sb" : "/web/20160127020422/http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#          })();
#       </script>
# <noscript>
#          &lt;img src="/web/20160127020422im_/http://b.scorecardresearch.com/p?c1=2&amp;amp;c2=7705242&amp;amp;cv=2.0&amp;amp;cj=1"&gt;
#       </noscript>
# <div class="LiquidHeader" id="mappingHeader">
# <a class="c21Logo" href="http://web.archive.org/web/20160127020422/http://www.century21.com/" onclick="Track.doEvent('Header', 'Logo');" title="CENTURY21 real estate, homes for sale and apartments for rent"></a>
# <span class="siteLinks">
# <a href="http://web.archive.org/web/20160127020422/http://espanol.century21.com/" onclick="Track.doEvent('Header', 'Offsite', 'Espanol');" title="Español">Español</a>
#                 |
#                <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/finehomes/" onclick="Track.doEvent('Header', 'Offsite', 'FHE');" title="Fine Homes">Fine Homes</a>
#                 |
#                <a href="http://web.archive.org/web/20160127020422/http://commercial.century21.com/" onclick="Track.doEvent('Header', 'Offsite', 'Commercial');" title="Commercial Real Estate">Commercial Real Estate</a>
#                 |
#                <a href="http://web.archive.org/web/20160127020422/http://century21global.com/" onclick="Track.doEvent('Header', 'Offsite', 'Global');" rel="nofollow" target="_blank" title="Global">Global</a>
#                 |
#                <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate-blog" onclick="Track.doEvent('Header', 'Offsite', 'Blog');" title="C21 Blog">C21 Blog</a>
# </span>
# <ul class="headerNav">
# <li><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property-search" id="NavigationFindHome" onclick="Track.doEvent('Header', 'Find A Home');" title="Find a Home">Find A Home</a></li>
# <li><div class="NavigationSeparator"></div></li>
# <li><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/careerfranchise" id="NavigationJoinC21" onclick="Track.doEvent('Header', 'Join C21');" title="Join C21">JoinC21</a></li>
# <li><div class="NavigationSeparator"></div></li>
# <li><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/buyingadvice" id="NavigationAdvice" onclick="Track.doEvent('Header', 'Advice');" title="Real Estate Advice">Advice</a></li>
# <li><div class="NavigationSeparator"></div></li>
# <li><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/calculators" id="NavigationTools" onclick="Track.doEvent('Header', 'Tools');" title="Real Estate Calculators">Tools</a></li>
# </ul>
# <div class="lmDropdown">
# <div id="dropdown">
# <div id="dropdownSearchBox">
# <input class="searchText" disabled="disabled" id="behindSearchText" name="behindFirstName" type="text"/>
# <input class="searchText searchValue" id="searchText" name="firstname" type="text" value=""/>
# <script>defer(function () { var search = portalAjax.getCookie("LAST_SEARCH_STRING"); $(".searchText").val(search || ""); });</script>
# <a href="javascript:void(0);" id="searchReset" onclick="Track.doEvent('Free Text Search', 'Reset Search');"></a>
# <a href="javascript:void(0);" id="searchButton"></a>
# </div>
# <div id="dropdownResults">
# <div id="dropdownRepeat"></div>
# <div id="dropdownResultsTop"></div>
# <div id="dropdownResultsBottom"></div>
# <div id="dropdownSearchContent" style="position:relative;display:none;">
# <div class="searchCriteria" id="searchCriteria">
# <span class="filterLabel">FILTERS</span>
# <input id="priceFrom" maxlength="8" name="priceFrom" size="8" style="display: none;" type="text" value=""/><div class="c21textdropdown priceFromInput generated_903_input"><div class="background">Min Price</div><input class="foreground" type="text"/></div>
# <input id="priceTo" maxlength="8" name="priceTo" size="8" style="display: none;" type="text" value=""/><div class="c21textdropdown generated_960_input"><div class="background">Max Price</div><input class="foreground" type="text"/></div>
# <select class="hide" id="priceOptions">
# <option value="$10,000">$10,000</option>
# <option value="$20,000">$20,000</option>
# <option value="$30,000">$30,000</option>
# <option value="$50,000">$50,000</option>
# <option value="$75,000">$75,000</option>
# <option value="$100,000">$100,000</option>
# <option value="$125,000">$125,000</option>
# <option value="$150,000">$150,000</option>
# <option value="$175,000">$175,000</option>
# <option value="$200,000">$200,000</option>
# <option value="$225,000">$225,000</option>
# <option value="$250,000">$250,000</option>
# <option value="$300,000">$300,000</option>
# <option value="$350,000">$350,000</option>
# <option value="$400,000">$400,000</option>
# <option value="$450,000">$450,000</option>
# <option value="$500,000">$500,000</option>
# <option value="$600,000">$600,000</option>
# <option value="$700,000">$700,000</option>
# <option value="$800,000">$800,000</option>
# <option value="$1,000,000">$1,000,000</option>
# <option value="$1,250,000">$1,250,000</option>
# <option value="$1,500,000">$1,500,000</option>
# <option value="$1,750,000">$1,750,000</option>
# <option value="$2,000,000">$2,000,000</option>
# <option value="$2,500,000">$2,500,000</option>
# <option value="$3,000,000">$3,000,000</option>
# </select>
# <select id="bedrooms" style="display: none;">
# <option optionforany="true" value="">Any Beds</option>
# <option value="1">1+</option>
# <option value="2">2+</option>
# <option value="3">3+</option>
# <option value="4">4+</option>
# <option value="5">5+</option>
# <option value="6">6+</option>
# </select><div class="selector smallSelector selectorCustomizations graySelectBox"><span>Any Beds</span><input class="generated_834_input" id="bedroomsFrom" name="bedroomsFrom" type="hidden" value=""/><input id="bedroomsTo" name="bedroomsTo" type="hidden" value=""/></div>
# <select id="bathrooms" style="display: none;">
# <option optionforany="true" value="">Any Baths</option>
# <option value="1">1+</option>
# <option value="2">2+</option>
# <option value="3">3+</option>
# <option value="4">4+</option>
# <option value="5">5+</option>
# <option value="6">6+</option>
# </select><div class="selector smallSelector selectorCustomizations graySelectBox"><span>Any Baths</span><input class="generated_147_input" id="bathroomsFrom" name="bathroomsFrom" type="hidden" value=""/><input id="bathroomsTo" name="bathroomsTo" type="hidden" value=""/></div>
# <select id="structureSize" style="display: none;">
# <option optionforany="true" value="">Any Sq. Ft.</option>
# <option value="250">250+</option>
# <option value="500">500+</option>
# <option value="1000">1000+</option>
# <option value="2500">2500+</option>
# <option value="5000">5000+</option>
# <option value="10000">10000+</option>
# </select><div class="selector smallSelector selectorSquareFeet graySelectBox"><span>Any Sq. Ft.</span><input class="generated_214_input" id="structureSizeFrom" name="structureSizeFrom" type="hidden" value=""/><input id="structureSizeTo" name="structureSizeTo" type="hidden" value=""/></div>
# </div>
# </div>
# <div id="dropdownContent">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="LiquidBody">
# <div class="LiquidSubHeader">
# <div id="BodyTopHeader">
# <span class="breadCrumbs">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/">CENTURY21 Real Estate</a> ›
#
#
#
#
#
#
#                <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/wyoming/LSWY/">Wyoming</a> ›
#
#
#
#
#
#
#                <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/">Rock Springs</a> ›
#
#
#
#
#
#
#
#                <span>Homes for Sale</span>
# </span>
# <script>
#    // DO NOT RUN TWICE
#    if (!window.g_pageLiquidLayout) {
#       // This must happen BEFORE dom ready
#       // (other scripts on this page depend on this variable existing);
#       window.g_pageLiquidLayout = new Century21.Maps.Page();
#    }
# </script>
# </div>
# <div id="myC21Header">
# <span class="subHeaderActions">
# <span class="actionLabel">My C21:</span>
# <span id="HeaderLoggedOff" style="display: inline;">
# <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Sign In'); myc21.loginForm.open();">Sign In</a>
#                          |  <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Create Account'); myc21.createAccountForm.open();">Register</a>
# <span id="hideMyC21"> |  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/myc21Overview.c21" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">My Favorites</a></span>
# </span>
# <span id="HeaderLoggedIn" style="display: none;">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/myc21Overview.c21" id="myc21UsernameLabel" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">Hi, <span id="myc21Username"></span></a>
#                       |  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/myc21Overview.c21" onclick="Track.doEvent('Header', 'MyC21', 'View Favorites');">My Favorites</a>
#                       |  <a href="javascript:void(0);" onclick="Track.doEvent('Header', 'MyC21', 'Sign Out'); myc21.logout();">Sign Out</a>
# </span>
# </span>
# </div>
# </div>
# <div class="SchoolsModalDiv" id="SchoolsModalDiv" style="display: none">
# <div class="schoolsToolTip" id="schoolsToolTip">
# <div class="contentTip" style="top: 335px;"></div>
# <input id="selectedSchoolIds" type="hidden" value=""/>
# <input id="hasRadiusSchools" type="hidden" value=""/>
# <input id="hasSchoolOutofBounds" type="hidden" value=""/>
# <input id="schoolAttendanceRadius" type="hidden" value=""/>
# <input id="schoolLocationOverride" type="hidden" value=""/>
# <input id="schoolSearchInitialized" initialized="Y" type="hidden" value="N"/>
# <input id="selectedSchoolFlags" type="hidden" value=""/>
# <input id="currSelectedSchoolID" type="hidden" value=""/>
# <div class="searchTabsSection" id="searchTabsSection">
# <div class="modalShowTopRated">
# <label for="modalTopRatedSchoolsRadio">
# <div class="radio" id="uniform-modalTopRatedSchoolsRadio"><span class=""><input checked="checked" id="modalTopRatedSchoolsRadio" name="modalSchoolTypeRadio" style="opacity: 0;" type="radio"/></span></div>Show Top Rated
#          </label>
# </div>
# <div class="modalYourSchools">
# <label class="selected" for="modalShowYourSchoolsRadio">
# <div class="radio" id="uniform-modalShowYourSchoolsRadio"><span class="checked"><input checked="checked" id="modalShowYourSchoolsRadio" name="modalSchoolTypeRadio" style="opacity: 0;" type="radio"/></span></div>Show Your Schools
#          </label>
# </div>
# <div class="sortByDiv">
# <label>Sort by: </label>
#          <div class="selector smallSelector" id="uniform-schoolSortTypes"><span>Rating</span><select id="schoolSortTypes" style="opacity: 0;">
# <option value="rating-desc">Rating</option>
# <option value="gsrating-desc">GreatSchools Rating</option>
# <option value="numstudents-asc">Number of Students (lowest first)</option>
# <option value="numstudents-desc">Number of Students (highest first)</option>
# <option value="stratio-asc">Student Teacher Ratio</option>
# <option value="name-asc">School Name A-Z</option>
# <option value="name-desc">School Name Z-A</option>
# <option value="numreviews-asc">Number of Reviews (lowest first)</option>
# <option value="numreviews-desc">Number of Reviews (highest first)</option>
# </select></div>
# </div>
# <div class="modalCloseDiv">
# <a href="javascript:void(0);" id="modalCloseLink" onclick="schoolSearch.closeWindow(); Track.doEvent('Schools', 'School Results Dialog', 'Close the school search results dialog');" title="Close"></a>
# </div>
# </div>
# <div class="clear"></div>
# <div class="searchCriteriaDiv">
# <div class="searchCriteriaSection">
# <div class="schoolNameDiv">
# <input class="defaulttext" id="schoolName" name="schoolName" type="text" value=""/>
# </div>
# <div class="schoolGradesDiv">
# <select id="lqschoolgrades" style="display: none;">
# <option optionforany="true" selecteddisplay="Grades" value="">Any</option>
# <option value="_GPS">Preschool</option>
# <option value="_GEL">Elementary</option>
# <option value="_GMI">Middle</option>
# <option value="_GHI">High School</option>
# <option value="-1|5">Kindergarten - 5th</option>
# <option value="6|8">6th - 8th</option>
# <option value="9|12">9th - 12th</option>
# <option value="_ADU">Adult</option>
# <option value="-2">Pre-Kindergarten</option>
# <option value="-1">Kindergarten</option>
# <option value="1">1st</option>
# <option value="2">2nd</option>
# <option value="3">3rd</option>
# <option value="4">4th</option>
# <option value="5">5th</option>
# <option value="6">6th</option>
# <option value="7">7th</option>
# <option value="8">8th</option>
# <option value="9">9th</option>
# <option value="10">10th</option>
# <option value="11">11th</option>
# <option value="12">12th</option>
# </select><div class="selector smallSelector lqselectorCustomizations"><span>Grades</span><input class="generated_483_input" id="lqschoolgradesFrom" name="lqschoolgradesFrom" type="hidden" value=""/><input id="lqschoolgradesTo" name="lqschoolgradesTo" type="hidden" value=""/></div>
# <input id="schoolgrade" type="hidden" value=""/>
# </div>
# <div class="schoolTypesDiv">
# <div class="selector smallSelector" id="uniform-lqschooltypes"><span>School Type</span><select id="lqschooltypes" style="opacity: 0;">
# <option selecteddisplay="School Type" value="">Any</option>
# <option value="public">Public</option>
# <option value="private">Private</option>
# <option value="state">State</option>
# <option value="catholic">Catholic</option>
# </select></div>
# </div>
# <div class="moreSearchOptionsSection">
# <div class="moreStudentOptions">
# <select id="lqstudents" style="display: none;">
# <option optionforany="true" selecteddisplay="Total # of Students" value="">Any</option>
# <option value="50">Less than 50</option>
# <option value="100">Less than 100</option>
# <option value="150">Less than 150</option>
# <option value="200">Less than 200</option>
# <option value="250">Less than 250</option>
# <option value="300">Less than 300</option>
# <option value="350">Less than 350</option>
# <option value="400">Less than 400</option>
# <option value="450">Less than 450</option>
# <option value="500">Less than 500</option>
# <option value="1000">Less than 1000</option>
# </select><div class="selector smallSelector lqselectorCustomizations"><span>Total # of Students</span><input class="generated_250_input" id="lqstudentsFrom" name="lqstudentsFrom" type="hidden" value=""/><input id="lqstudentsTo" name="lqstudentsTo" type="hidden" value=""/></div>
# <select id="lqstudentratio" style="display: none;">
# <option optionforany="true" selecteddisplay="Student/Teacher Ratio" value="">Any</option>
# <option value="10">Less than 10:1</option>
# <option value="20">Less than 20:1</option>
# <option value="30">Less than 30:1</option>
# <option value="40">Less than 40:1</option>
# <option value="50">Less than 50:1</option>
# <option value="100">Less than 100:1</option>
# </select><div class="selector smallSelector lqselectorCustomizations"><span>Student/Teacher Ratio</span><input class="generated_848_input" id="lqstudentratioFrom" name="lqstudentratioFrom" type="hidden" value=""/><input id="lqstudentratioTo" name="lqstudentratioTo" type="hidden" value=""/></div>
# </div>
# <div class="header">Refined Search Options</div>
# <div class="searchOptionsColumn1">
# <div class="flagoption"><label for="schoolFlag_ADP"><div class="checker" id="uniform-schoolFlag_ADP"><span><input class="schoolFlagCheckbox" id="schoolFlag_ADP" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Advanced Placement</span></label></div>
# <div class="flagoption"><label for="schoolFlag_BAS"><div class="checker" id="uniform-schoolFlag_BAS"><span><input class="schoolFlagCheckbox" id="schoolFlag_BAS" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Before and After School Programs</span></label></div><br/>
# <div class="flagoption"><label for="schoolFlag_BRS"><div class="checker" id="uniform-schoolFlag_BRS"><span><input class="schoolFlagCheckbox" id="schoolFlag_BRS" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Blue Ribbon School</span></label></div>
# <div class="flagoption"><label for="schoolFlag_CES"><div class="checker" id="uniform-schoolFlag_CES"><span><input class="schoolFlagCheckbox" id="schoolFlag_CES" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Coalition of Essential School</span></label></div><br/>
# <div class="flagoption"><label for="schoolFlag_CHA"><div class="checker" id="uniform-schoolFlag_CHA"><span><input class="schoolFlagCheckbox" id="schoolFlag_CHA" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Charter School</span></label></div>
# <div class="flagoption"><label for="schoolFlag_GAT"><div class="checker" id="uniform-schoolFlag_GAT"><span><input class="schoolFlagCheckbox" id="schoolFlag_GAT" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Gifted and Talented</span></label></div>
# <div class="flagoption"><label for="schoolFlag_IBC"><div class="checker" id="uniform-schoolFlag_IBC"><span><input class="schoolFlagCheckbox" id="schoolFlag_IBC" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">International Baccalaureate</span></label></div>
# <div class="flagoption"><label for="schoolFlag_MAG"><div class="checker" id="uniform-schoolFlag_MAG"><span><input class="schoolFlagCheckbox" id="schoolFlag_MAG" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Magnet School</span></label></div>
# <div class="flagoption"><label for="schoolFlag_SIT"><div class="checker" id="uniform-schoolFlag_SIT"><span><input class="schoolFlagCheckbox" id="schoolFlag_SIT" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Site Based</span></label></div>
# </div>
# <div class="searchOptionsColumn2">
# <div class="flagoption"><label for="schoolFlag_VOC"><div class="checker" id="uniform-schoolFlag_VOC"><span><input class="schoolFlagCheckbox" id="schoolFlag_VOC" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Vocational/Tech</span></label></div>
# <div class="flagoption"><label for="schoolFlag_ADU"><div class="checker" id="uniform-schoolFlag_ADU"><span><input class="schoolFlagCheckbox" id="schoolFlag_ADU" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Adult Education Classes</span></label></div>
# <div class="flagoption"><label for="schoolFlag_SPE"><div class="checker" id="uniform-schoolFlag_SPE"><span><input class="schoolFlagCheckbox" id="schoolFlag_SPE" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Special Education</span></label></div>
# <div class="flagoption"><label for="schoolFlag_APR"><div class="checker" id="uniform-schoolFlag_APR"><span><input class="schoolFlagCheckbox" id="schoolFlag_APR" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Alternative Programs</span></label></div>
# <div class="flagoption"><label for="schoolFlag_YRC"><div class="checker" id="uniform-schoolFlag_YRC"><span><input class="schoolFlagCheckbox" id="schoolFlag_YRC" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">Year Round Classes</span></label></div>
# <div class="flagoption"><label for="schoolFlag_ESL"><div class="checker" id="uniform-schoolFlag_ESL"><span><input class="schoolFlagCheckbox" id="schoolFlag_ESL" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">ESL</span></label></div>
# <div class="flagoption"><label for="schoolFlag_AYP"><div class="checker" id="uniform-schoolFlag_AYP"><span><input class="schoolFlagCheckbox" id="schoolFlag_AYP" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">AYP School</span></label></div>
# <div class="flagoption"><label for="schoolFlag_NCL"><div class="checker" id="uniform-schoolFlag_NCL"><span><input class="schoolFlagCheckbox" id="schoolFlag_NCL" style="opacity: 0;" type="checkbox"/></span></div><span class="infoLabel">NCLB School</span></label></div>
# <div class="submitOptionsButton"><a href="javascript:void(0);" id="submitOptions" onclick="Track.doEvent('Schools', 'School Results Dialog', 'Filter by Refined Search Options'); schoolSearch.hideMoreSearchOptions();"></a></div>
# </div>
# </div>
# </div>
# <a class="moreSearchOptionsLink" href="javascript:void(0);">More School Options</a>
# </div>
# <div class="schoolSearchResults searchListSection" id="schoolSearchResults"></div>
# <div class="schoolDetailInformation" id="schoolDetailInformation"></div>
# </div>
# </div>
# <div class="SchoolModalRadiusSelect" id="SchoolModalRadiusSelect" style="display: none">
# <div id="SchoolRadiusModalWindow">
# <div id="modalBackdrop"></div>
# <div class="schoolRadiusBox" style="top: 240px; ">
# <div id="modalContent">
# <form id="schoolRadiusForm">
# <div class="header">Choose a radius</div><br/>
# <div class="info">The school you chose doesn't have a designated attendance area.</div>
# <div class="info">Please choose a radius to apply for schools without attendance zones.</div><br/>
# <div class="schoolRadiusButtons">
# <div class="selector smallSelector" id="uniform-schoolRadiusSelector"><span>1 Mile</span><select id="schoolRadiusSelector" style="opacity: 0;">
# <option value="1">1 Mile</option>
# <option value="2">2 Miles</option>
# <option value="3">3 Miles</option>
# <option value="4">4 Miles</option>
# <option value="5">5 Miles</option>
# <option value="10">10 Miles</option>
# <option value="15">15 Miles</option>
# <option value="20">20 Miles</option>
# <option value="25">25 Miles</option>
# <option value="30">30 Miles</option>
# <option value="35">35 Miles</option>
# <option value="40">40 Miles</option>
# <option value="45">45 Miles</option>
# <option value="50">50 Miles</option>
# </select></div>
# <a href="javascript:void(0);" id="radiusModalSubmitButton" onclick="schoolSearch.closeRadiusSelectDialog();"></a>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script>
#    defer(function () {
#       $("#schoolRadiusSelector").uniform();
#       $("#schoolRadiusSelector").change(function() {
#          Track.doEvent('Schools', 'Choose Attendance Radius Dialog', 'Change Radius', parseInt($("#schoolRadiusSelector option:selected").text()));
#       });
#    });
# </script>
# </div>
# <div class="SchoolModalBoundary" id="SchoolModalBoundary" style="display: none">
# <div id="SchoolBoundaryModalWindow">
# <div id="modalBackdrop"></div>
# <div class="schoolBoundaryBox" style="top: 240px; ">
# <div id="modalContent">
# <form id="schoolBoundaryForm">
# <div class="header">Use School Boundaries?</div>
# <div class="infoLine1">Homes exist outside of <span class="schoolBoundaryLocation"> Rock Springs, WY</span> that attend your chosen schools.</div>
# <div class="infoLine2">Do you want to include these homes in your search results?</div>
# <div class="schoolBoundaryButtons">
# <a href="javascript:void(0);" id="schoolBoundaryYesButton" onclick="schoolSearch.closeBoundarySelectDialog('Y');"></a>
# <a href="javascript:void(0);" id="schoolBoundaryNoButton" onclick="schoolSearch.closeBoundarySelectDialog('N');"></a>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script>
#    defer(function () {
#       $(".schoolBoundaryLocation").text(" " + $("#searchText").val());
#    });
# </script>
# </div>
# <div class="SchoolModalDeletion" id="SchoolModalDeletion" style="display: none">
# <div id="SchoolDeletionModalWindow">
# <div id="modalBackdrop"></div>
# <div class="schoolDeletionBox" style="top: 240px; ">
# <div id="modalContent">
# <form id="schoolDeletionForm">
# <div class="header">Delete Selected Schools?</div>
# <div class="infoLine1">You have schools selected. Changing location will delete your selected schools.</div>
# <div class="infoLine2">Do you want to proceed?</div>
# <div class="schoolDeletionButtons">
# <a href="javascript:void(0);" id="schoolDeletionYesButton" onclick="schoolSearch.closeDeletionSelectDialog('Y');"></a>
# <a href="javascript:void(0);" id="schoolDeletionNoButton" onclick="schoolSearch.closeDeletionSelectDialog('N');"></a>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <input id="discontinuedType" type="hidden" value=""/>
# <div class="DiscontinuedTypeModal" id="DiscontinuedTypeModal" style="display: none">
# <div id="DiscontinuedTypeModalWindow">
# <div id="modalBackdrop"></div>
# <div class="discontinuedTypeBox" style="top: 240px; ">
# <div id="modalContent">
# <div class="modalCloseDiv">
# <a href="javascript:void(0);" id="discontinuedTypeCloseLink" onclick="closeDiscontinuedTypeModal();" title="Close"></a>
# </div>
# <form id="discontinuedTypeForm">
# <div class="topSection">
# <div class="header">
#
#
#                         We're sorry, the property you are looking for could not be found.
#
#
#
#
#                </div>
# </div>
# <div class="centerSection">
# <div class="infoHeader">
#
#
#                         View Other Properties in
#
#
#
#
#                </div>
# <div class="locationLine"></div>
# <div class="continueButtonDiv"><a href="javascript:void(0);" id="discontinuedTypeContinueLink" onclick="closeDiscontinuedTypeModal();" title="Continue"></a></div>
# </div>
# <div class="bottomSection">
# <div class="infoLine">
#
#
#                         Or see properties in:
#
#
#
#
#                </div>
# <div class="otherLocations"><span class="zipLocation"><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" title=""></a></span><span class="countyLocation"><a href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS" title=""></a></span></div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#    function closeDiscontinuedTypeModal() {
#       $("#DiscontinuedTypeModal").hide();
#    }
#
#    $(document).ready(function() {
#       var discontinuedType = $("#discontinuedType").val();
#       if(discontinuedType == "1") {
#          $("#DiscontinuedTypeModal").show();
#       }
#    });
# </script></div>
# <div class="LiquidBodyLeft" id="BodyLeftLane">
# <div class="currentSrBox" id="currentSrBox">
# <div class="LaneTitle leftLaneTitleSection">
# <div class="verticalCenter">
# <div class="leftLaneTitle">Your Current Search</div>
# <div id="saveSearch" style="display: block;">
# <a class="saveSearchLink" href="javascript:void(0);" id="saveSearchButton" onclick="Track.doEvent('Hybrid Mapping', 'Left Lane', 'Select Login to My C21 to Save Search'); myc21.      loginForm.open(true);">
#                         save search
#                      </a>
# <span class="saveSearchDivider" style="display: none;"> | </span>
# <a class="clearAll" href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/?v=3" id="clearAll" onclick="return portalResults.clearLiquidMapFacets();" style="display: none;"> clear all</a>
# </div>
# </div>
# </div>
# <div id="currentSearch">
# <div class="LaneText currentSearchItems">
# <input id="textSearched" name="textSearched" type="hidden" value=""/>
# <h4>Homes for Sale</h4>
#       Rock Springs, WY
#
#
#
#    <script type="text/javascript">
#       $("#selectedSchoolIds").val('');
#    </script>
# <input id="selectedSchoolBounds" type="hidden" value=""/>
# <input id="selectedSchoolLocations" type="hidden" value=""/>
# </div>
# <script>
#    $(document).ready(function() {
#       //Hide/show the clear all link
#       var removecount = '0';
#       if(removecount > 1) {
#          $("#clearAll").show();
#          $(".saveSearchDivider").show();
#       } else {
#          $("#clearAll").hide();
#          $(".saveSearchDivider").hide();
#       }
#    });
# </script>
# </div>
# <a class="currentSearchSlider" href="javascript:void(0);" style="display: none;"></a>
# </div>
# <div id="refineSearch">
# <input id="cacheServerSearchURL" name="cacheServerSearchURL" type="hidden" value="&amp;lid=CWYROCKSPRINGS&amp;xbc=ENX&amp;rpp=10&amp;so=desc&amp;start=0&amp;sf=price"/>
# <input id="searchLocationLIDS" name="searchLocationLIDS" type="hidden" value="CWYROCKSPRINGS"/>
# <div id="stdSearchFields">
# <div class="LaneTitle leftLaneTitle">Refine Your Search</div>
# <input id="lqRefineType" name="lqRefineType" type="hidden" value="PROPERTIES"/>
# <div class="LaneText refineSection priceSection">
# <div>
# <div style="float:left;">
# <label class="refineLabel">Price Range</label>
# <input id="lqMinPriceHidden" style="display: none;" type="hidden" value=""/><div class="selector smallSelector lqselectorCustomizations generated_791_input"><span></span></div>
# <div class="lqPriceMiddle">to</div>
# <input id="lqMaxPriceHidden" style="display: none;" type="hidden" value=""/><div class="selector smallSelector lqselectorCustomizations lqselectorCustomizationsPriceMax generated_296_input"><span></span></div>
# </div>
# </div>
# </div>
# <div class="LaneText refineSection bedsBathsSection">
# <div>
# <div class="bedsSection">
# <label class="refineLabel">Beds</label>
# <select id="lqbedrooms" style="display: none;">
# <option value="">Any</option>
# <option value="1">1+</option>
# <option value="2">2+</option>
# <option value="3">3+</option>
# <option value="4">4+</option>
# <option value="5">5+</option>
# <option value="6">6+</option>
# </select><div class="selector smallSelector lqselectorCustomizations"><span>Any</span><input class="generated_722_input" id="lqbedroomsFrom" name="lqbedroomsFrom" type="hidden" value=""/><input id="lqbedroomsTo" name="lqbedroomsTo" type="hidden" value=""/></div>
# <input id="lqMinBedHidden" type="hidden" value=""/>
# <input id="lqMaxBedHidden" type="hidden" value=""/>
# </div>
# <div class="bathsSection">
# <label class="refineLabel">Baths</label>
# <select id="lqbathrooms" style="display: none;">
# <option value="">Any</option>
# <option value="1">1+</option>
# <option value="2">2+</option>
# <option value="3">3+</option>
# <option value="4">4+</option>
# <option value="5">5+</option>
# <option value="6">6+</option>
# </select><div class="selector smallSelector lqselectorCustomizations"><span>Any</span><input class="generated_419_input" id="lqbathroomsFrom" name="lqbathroomsFrom" type="hidden" value=""/><input id="lqbathroomsTo" name="lqbathroomsTo" type="hidden" value=""/></div>
# <input id="lqMinBathHidden" type="hidden" value=""/>
# <input id="lqMaxBathHidden" type="hidden" value=""/>
# </div>
# <div class="clear"></div>
# </div>
# <label class="refineLabel">Square Footage</label>
# <select id="lqstructureSize" style="display: none;">
# <option value="">Any</option>
# <option value="250">250+</option>
# <option value="500">500+</option>
# <option value="1000">1000+</option>
# <option value="2500">2500+</option>
# <option value="5000">5000+</option>
# <option value="10000">10000+</option>
# </select><div class="selector smallSelector selectorSquareFeet"><span>Any</span><input class="generated_576_input" id="lqstructureSizeFrom" name="lqstructureSizeFrom" type="hidden" value=""/><input id="lqstructureSizeTo" name="lqstructureSizeTo" type="hidden" value=""/></div>
# <input id="lqMinSqftHidden" type="hidden" value=""/>
# <input id="lqMaxSqftHidden" type="hidden" value=""/>
# </div>
# <div class="LaneText refineSection" id="keywordSection">
# <div class="newfangledInput">
# <label>Keyword</label>
# <input id="keywordText" type="text" value=""/>
# <a class="updateArrow" href="javascript:void(0);" id="keywordUpdateButton"></a>
# </div>
# </div>
# <div class="LaneText refineSection refineLocation" id="schSearch">
# <div class="schoolsRefine">
# <a class="includeSchoolsLink" href="javascript:void(0);" id="schoolsLiqMapButton">Search by Schools</a>
# <div class="SchoolSearchBanner" id="SchoolSearchBanner" style="top: 335px; width: 0px; display: none;"></div>
# <div class="schoolSearchTypesSection">
# <label for="topRatedSchoolsRadio">
# <div class="radio" id="uniform-topRatedSchoolsRadio"><span><input id="topRatedSchoolsRadio" name="schoolTypeRadio" style="opacity: 0;" type="radio"/></span></div>Show Top Rated
#                   </label> <br/>
# <label for="showYourSchoolsRadio">
# <div class="radio" id="uniform-showYourSchoolsRadio"><span><input id="showYourSchoolsRadio" name="schoolTypeRadio" style="opacity: 0;" type="radio"/></span></div>Show Your Schools
#                   </label>
# </div>
# </div>
# <div class="surroundAreas">
# <a class="includeAreaLink" href="javascript:void(0);" id="surroundingAreasLiqMap">Add Surrounding Area</a>
# </div>
# <div class="newfangledInput" id="locationSection">
# <label></label>
# <input id="refineText" name="refine" type="text" value="Rock Springs, WY"/>
# <a class="updateArrow" href="javascript:void(0);" id="locationUpdateButton"></a>
# </div>
# </div>
# <div class="LaneText refineSection" id="mlsSection">
# <div class="newfangledInput">
# <label>MLS #</label>
# <input id="mlsSearch" name="refine" type="text" value=""/>
# <a class="updateArrow" href="javascript:void(0);" id="mlsUpdateButton"></a>
# </div>
# </div>
# </div>
# <div class="morePropSearchOptionsSection sch" id="morePropSearchOptionsSection" style="height: 68px; display: none;">
# <div class="LaneText searchOptionsTitle">
#          More Search Options
#       </div>
# <!-- View All Search Options Section -->
# <div class="searchOptions">
# <div class="LaneText refineSection allOrNothing" id="facetGroup-la">
# <label class="refineLabel">Listing Activity</label>
# <div class="refineItem">
# <label class="lqOptionTypeLabel">
# <input class="propOptionCheckbox" onclick="return portalResults.addListFacet('fo', '1');" type="checkbox"/>
# <span class="propOptionLabel">
#                                  Foreclosure
#                                   (5)
#                               </span>
# </label>
# </div>
# </div>
# <div class="LaneText refineSection allOrNothing" id="facetGroup-ty">
# <label class="refineLabel">Listing Type</label>
# <div class="refineItem">
# <label class="lqOptionTypeLabel">
# <input class="propOptionCheckbox" onclick="return portalResults.addListFacet('co', '1');" type="checkbox"/>
# <span class="propOptionLabel">
#                                  Only C21 Listings
#                                   (3)
#                               </span>
# </label>
# </div>
# </div>
# <div class="LaneText refineSection allOrNothing" id="facetGroup-pt">
# <label class="refineLabel">Property Type</label>
# <div class="refineItem">
# <label class="lqOptionTypeLabel">
# <input class="propOptionCheckbox" onclick="return portalResults.addListFacet('pt', '1');" type="checkbox"/>
# <span class="propOptionLabel">
#                                  Single Family Home
#                                   (19)
#                               </span>
# </label>
# </div>
# <div class="refineItem">
# <label class="lqOptionTypeLabel">
# <input class="propOptionCheckbox" onclick="return portalResults.addListFacet('pt', '2');" type="checkbox"/>
# <span class="propOptionLabel">
#                                  Condo/Townhome
#                                   (3)
#                               </span>
# </label>
# </div>
# <div class="refineItem">
# <label class="lqOptionTypeLabel">
# <input class="propOptionCheckbox" onclick="return portalResults.addListFacet('pt', '8');" type="checkbox"/>
# <span class="propOptionLabel">
#                                  Mobile/Manufactured
#                                   (2)
#                               </span>
# </label>
# </div>
# </div>
# <div class="LaneText refineSection allOrNothing" id="facetGroup-fg14">
# <label class="refineLabel">Age</label>
# <div class="refineItem">
# ...
#         } else {
#           jFooterPanel
#             .removeClass("closed")
#             .addClass("opened");
#           $(detailsElement).show();
#         }
#     }
#
#     //Close the site map panel
#     function closePanel(jFooterPanel, detailsElement) {
#         if (jFooterPanel .hasClass("opened")) {
#           jFooterPanel
#             .removeClass("opened")
#             .addClass("closed");
#           $(detailsElement).hide();
#         }
#     }
# </script>
# <link href="./LCWYROCKSPRINGS1_files/defaultLiquidMapCSS.css" rel="stylesheet"/>
# <script src="./LCWYROCKSPRINGS1_files/defaultLiquidMapJS.js"></script>
# <script src="./LCWYROCKSPRINGS1_files/dynamic.js"></script>
# </div>
# </div>
# <div class="LiquidBodyMain mapNormal" id="LiquidBodyMain" style="z-index: -1;">
# <div class="LiquidBodySubheaderRight" id="BodyRightLane">
# <div class="LaneTitle" data-count="26" id="rightNavLiquidMap">
# <h1>
#             Rock Springs, WY Real Estate &amp; Homes for Sale
#             <span class="numResultSeperator"> - </span>
# <span class="numResultsCount">26 Listings Found</span>
# </h1>
# <input id="mapBoundary" name="mapBoundary" type="hidden" value=""/>
# <input id="drawingToolBoundary" name="drawingToolBoundary" type="hidden" value=""/>
# <input id="searchLocationLatitude" name="searchLocationLatitude" type="hidden" value="41.63405"/>
# <input id="searchLocationLongitude" name="searchLocationLongitude" type="hidden" value="-108.9935"/>
# <div class="clear"></div>
# </div>
# <input id="searchWithinMapEnabled" type="hidden" value="false"/>
# <label class="searchMap">Search Within Map <input id="searchWithinMap" name="searchWithinMap" type="checkbox"/></label>
# </div>
# <div id="mapContainer">
# <div id="bingMap">
# <div id="typeContainer">
# <a class="option selected" href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS#" id="bingMapTypeAutomatic">Automatic</a>
# <a class="option notSelected" href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS#" id="bingMapTypeRoad">Road</a>
# <a class="option notSelected" href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS#" id="bingMapTypeBE">Bird's Eye</a>
# <a class="option notSelected last" href="http://web.archive.org/web/20160127020422/http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS#" id="bingMapTypeAerial">Aerial</a>
# </div>
# <div class="panelToggle opened" id="panelToggleControl"></div>
# <div class="panelToggle closed" id="fullListToggleControl"></div>
# </div>
# <div class="mapToolTip" id="myPlacesToolInstructions" style="">
#                MY PLACES<br/>
#                Locate important places on the map like school, work, and home of a relative or friend to help find the best properties for you.<br/>
# <span class="addPlaceLink">Add, Edit, or View My Places</span>
# <div class="mapToolTipClose" onclick="$('#myPlacesToolInstructions').removeClass('active');" title="Click to close."></div>
# <div class="mapToolTipPointer"></div>
# </div>
# <div class="mapToolTip" id="drawingToolInstructions" style="">
#                DRAWING TOOL<br/>
#                Draw the area on the map that you would like to search.
#                Click the pencil icon again to turn the drawing tool off.
#                <div class="mapToolTipClose" onclick="$('#drawingToolInstructions').removeClass('active');" title="Click to close."></div>
# <div class="mapToolTipPointer"></div>
# </div>
# <div class="mapToolTip" id="mapToolTip">
# <span id="mapToolTipText">DRAWING TOOL</span>
# <div class="mapToolTipPointer"></div>
# </div>
# <div class="overlayToolTip" style="display:none;">
# <span id="overlayToolTipText"></span>
# <div class="overlayToolTipPointer"></div>
# </div>
# <div id="heatMapLabel"></div>
# <div class="mapToolsArea">
# <div class="topToolArea">
# <div class="pinBtn" id="myPlacesTool"></div>
# <div class="drawBtn" id="drawTool"></div>
# <div class="prevBtn disabled" id="prevBtn"></div>
# <div class="btnShim"></div>
# <div class="nextBtn" id="nextBtn"></div>
# </div>
# <div class="clear"></div>
# <div class="panelToggleButton mapToolsBtn" href="#bottomMapToolsDropDown" id="bottomMapTools"></div>
# </div>
# <div id="panelBottom">
# <div id="panelContent">
# <div class="panelOption" id="bottomMapToolsDropDown">
# <div class="pointsOfInterestDiv" id="pointsOfInterestDiv">
# <div class="mapToolTitle">Points Of Interest</div>
# <div class="pointsOfInterestLeftDiv" id="pointsOfInterestLeftDiv">
# <div class="pointOfInterest" id="banksPOI">
# <label for="banksPOIItem"><div class="poiIconLegend IconPoiBanks16"></div>
# <div class="checker" id="uniform-banksPOIItem"><span><input class="pointOfInterestCheckbox" id="banksPOIItem" style="opacity: 0;" type="checkbox" value="banks"/></span></div>Banks</label>
# </div>
# <div class="pointOfInterest" id="recreationPOI">
# <label for="recreationPOIItem"><div class="poiIconLegend IconPoiRecreation16"></div>
# <div class="checker" id="uniform-recreationPOIItem"><span><input class="pointOfInterestCheckbox" id="recreationPOIItem" style="opacity: 0;" type="checkbox" value="recreation"/></span></div>Recreation</label>
# </div>
# <div class="pointOfInterest" id="foodDrinkPOI">
# <label for="foodDrinkPOIItem"><div class="poiIconLegend IconPoiFood16"></div>
# <div class="checker" id="uniform-foodDrinkPOIItem"><span><input class="pointOfInterestCheckbox" id="foodDrinkPOIItem" style="opacity: 0;" type="checkbox" value="food &amp; drinks"/></span></div>Food &amp; Drinks</label>
# </div>
# <div class="pointOfInterest" id="educationPOI">
# <label for="educationPOIItem"><div class="poiIconLegend IconPoiEducation16"></div>
# <div class="checker" id="uniform-educationPOIItem"><span><input class="pointOfInterestCheckbox" id="educationPOIItem" style="opacity: 0;" type="checkbox" value="education"/></span></div>Education</label>
# </div>
# <div class="pointOfInterest" id="servicesPOI">
# <label for="servicesPOIItem"><div class="poiIconLegend IconPoiServices16"></div>
# <div class="checker" id="uniform-servicesPOIItem"><span><input class="pointOfInterestCheckbox" id="servicesPOIItem" style="opacity: 0;" type="checkbox" value="services"/></span></div>Services</label>
# </div>
# <div class="pointOfInterest" id="travelPOI">
# <label for="travelPOIItem"><div class="poiIconLegend IconPoiTravel16"></div>
# <div class="checker" id="uniform-travelPOIItem"><span><input class="pointOfInterestCheckbox" id="travelPOIItem" style="opacity: 0;" type="checkbox" value="travel"/></span></div>Travel</label>
# </div>
# </div>
# <div class="pointsOfInterestRightDiv" id="pointsOfInterestRightDiv">
# <div class="pointOfInterest" id="governmentPOI">
# <label for="governmentPOIItem"><div class="poiIconLegend IconPoiGovernment16"></div>
# <div class="checker" id="uniform-governmentPOIItem"><span><input class="pointOfInterestCheckbox" id="governmentPOIItem" style="opacity: 0;" type="checkbox" value="government"/></span></div>Government</label>
# </div>
# <div class="pointOfInterest" id="worshipPOI">
# <label for="worshipPOIItem"><div class="poiIconLegend IconPoiPlacesOfWorship16"></div>
# <div class="checker" id="uniform-worshipPOIItem"><span><input class="pointOfInterestCheckbox" id="worshipPOIItem" style="opacity: 0;" type="checkbox" value="places of worship"/></span></div>Places of Worship</label>
# </div>
# <div class="pointOfInterest" id="healthPOI">
# <label for="healthPOIItem"><div class="poiIconLegend IconPoiHealthCare16"></div>
# <div class="checker" id="uniform-healthPOIItem"><span><input class="pointOfInterestCheckbox" id="healthPOIItem" style="opacity: 0;" type="checkbox" value="health care"/></span></div>Health Care</label>
# </div>
# <div class="pointOfInterest" id="shoppingPOI">
# <label for="shoppingPOIItem"><div class="poiIconLegend IconPoiShopping16"></div>
# <div class="checker" id="uniform-shoppingPOIItem"><span><input class="pointOfInterestCheckbox" id="shoppingPOIItem" style="opacity: 0;" type="checkbox" value="shopping"/></span></div>Shopping</label>
# </div>
# <div class="pointOfInterest" id="petsPOI">
# <label for="petsPOIItem"><div class="poiIconLegend IconPoiPetServices16"></div>
# <div class="checker" id="uniform-petsPOIItem"><span><input class="pointOfInterestCheckbox" id="petsPOIItem" style="opacity: 0;" type="checkbox" value="pet services"/></span></div>Pet Services</label>
# </div>
# </div>
# </div>
# <div class="areaOverlaysDiv" id="areaOverlaysDiv">
# <div class="mapToolTitle">
#                            Area Overlay
#                            <div class="heatMapLegend"><span id="legendLowRange">$50K</span> <img height="10" src="./LCWYROCKSPRINGS1_files/lm-overlay-meter.png" width="91"/> <span id="legendHighRange">$1M+</span></div>
# </div>
# <div class="areaOverlayOptions">
# <div class="areaOverlayOptionsDivide">
# <div class="areaOverlayHeader">
#                                  Heat maps are viewable one at a time.<br/>
#                                  Click the buttons to toggle them on or off.
#                               </div>
# <div class="overlayOption">
# <div class="areaOverlay medianIncome" id="areaOverlayIncome" metatype="medianIncome"></div>
# </div>
# <div class="overlayOption">
# <div class="areaOverlay medianAge" id="areaOverlayAge" metatype="medianAge"></div>
# </div>
# <div class="overlayOption">
# <div class="areaOverlay medianHomePrice" id="areaOverlayPrice" metatype="medianHomePrice"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div id="lassoTool"></div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#       /* <![CDATA[ */
#       var google_conversion_id = 995114485;
#       var google_conversion_label = "savpCJOH4AMQ9fvA2gM";
#       var google_custom_params = window.google_tag_params;
#       var google_remarketing_only = true;
#       /* ]]> */
#    </script>
# <script src="./LCWYROCKSPRINGS1_files/conversion.js" type="text/javascript">
# </script><iframe allowtransparency="true" frameborder="0" height="13" hspace="0" marginheight="0" marginwidth="0" name="google_conversion_frame" scrolling="no" src="./LCWYROCKSPRINGS1_files/saved_resource.html" title="Google conversion frame" vspace="0" width="300">&lt;img height="1" width="1" border="0" alt="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/995114485/?frame=0&amp;random=1470951004806&amp;cv=8&amp;fst=1470951004806&amp;num=1&amp;fmt=1&amp;label=savpCJOH4AMQ9fvA2gM&amp;guid=ON&amp;eid=3455315&amp;u_h=720&amp;u_w=1280&amp;u_ah=720&amp;u_aw=1280&amp;u_cd=24&amp;u_his=2&amp;u_tz=120&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=7&amp;frm=0&amp;url=http%3A//web.archive.org/web/20160127020422/http%3A//www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS&amp;ref=http%3A//web.archive.org/web/*/http%3A//www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/&amp;tiba=Rock%20Springs%20Real%20Estate%20%7C%20Find%20Houses%20%26%20Homes%20for%20Sale%20in%20Rock%20Springs%2C%20WY" /&gt;</iframe>
# <noscript>
#       &lt;div style="display:inline;"&gt;
#       &lt;img height="1" width="1" style="border-style:none;" alt="" src="/web/20160127020422im_/http://googleads.g.doubleclick.net/pagead/viewthroughconversion/995114485/?value=0&amp;amp;label=savpCJOH4AMQ9fvA2gM&amp;amp;guid=ON&amp;amp;script=0"/&gt;
#       &lt;/div&gt;
#    </noscript>
# <div class="clear"></div>
# <div id="ModalWindow"></div>
# <script src="./LCWYROCKSPRINGS1_files/ScriptProvider.php" type="text/javascript"></script><script src="./LCWYROCKSPRINGS1_files/ScriptProviderReal.php" type="text/javascript"></script>
# <script>
# $.each(window.m_aDeferredMethods, function (i, fn) { fn(); });
# window.m_aDeferredMethods = false;
# </script>
# <script id="uiBindings">
#
# portalSearch.createSearchField();
#
#
# portalResults.createResultsPage('10', 'price-desc', 3, 'results');window.viewEngineName='search';</script>
# <!--
#      FILE ARCHIVED ON 2:04:22 Jan 27, 2016 AND RETRIEVED FROM THE
#      INTERNET ARCHIVE ON 21:29:40 Aug 11, 2016.
#      JAVASCRIPT APPENDED BY WAYBACK MACHINE, COPYRIGHT INTERNET ARCHIVE.
#
#      ALL OTHER CONTENT MAY ALSO BE PROTECTED BY COPYRIGHT (17 U.S.C.
#      SECTION 108(a)(3)).
# -->
# <div class="dropdownBox dropdownCustomizations" id="generated_834" showing="false" style="top: -9999px; left: -9999px; display: block;"><div class="dropdownHeader"><div class="dropdownHeaderContainer"><div class="dropdownTo">to</div><div class="dropdownHeaderStart"><div class="background">Min</div><input class="foreground" maxlength="2" tabindex="102" type="text"/></div><div class="dropdownHeaderEnd"><div class="background">Max</div><input class="foreground" maxlength="2" tabindex="103" type="text"/></div></div></div><div class="dropdownOptionViewport"><div class="dropdownOptionContainer"><div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">Any Beds</div><div class="dropdownOption" value="1">1+</div><div class="dropdownOption dropdownOptionOdd" value="2">2+</div><div class="dropdownOption" value="3">3+</div><div class="dropdownOption dropdownOptionOdd" value="4">4+</div><div class="dropdownOption" value="5">5+</div><div class="dropdownOption dropdownOptionOdd" value="6">6+</div></div></div></div><div class="dropdownBox dropdownCustomizations" id="generated_147" showing="false" style="top: -9999px; left: -9999px; display: block;"><div class="dropdownHeader"><div class="dropdownHeaderContainer"><div class="dropdownTo">to</div><div class="dropdownHeaderStart"><div class="background">Min</div><input class="foreground" maxlength="2" tabindex="104" type="text"/></div><div class="dropdownHeaderEnd"><div class="background">Max</div><input class="foreground" maxlength="2" tabindex="105" type="text"/></div></div></div><div class="dropdownOptionViewport"><div class="dropdownOptionContainer"><div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">Any Baths</div><div class="dropdownOption" value="1">1+</div><div class="dropdownOption dropdownOptionOdd" value="2">2+</div><div class="dropdownOption" value="3">3+</div><div class="dropdownOption dropdownOptionOdd" value="4">4+</div><div class="dropdownOption" value="5">5+</div><div class="dropdownOption dropdownOptionOdd" value="6">6+</div></div></div></div><div class="dropdownBox dropdownCustomizations" id="generated_214" showing="false" style="top: -9999px; left: -9999px; display: block;"><div class="dropdownHeader"><div class="dropdownHeaderContainer"><div class="dropdownTo">to</div><div class="dropdownHeaderStart"><div class="background">Min</div><input class="foreground" maxlength="7" tabindex="106" type="text"/></div><div class="dropdownHeaderEnd"><div class="background">Max</div><input class="foreground" maxlength="7" tabindex="107" type="text"/></div></div></div><div class="dropdownOptionViewport"><div class="dropdownOptionContainer"><div class="dropdownOption dropdownOptionOdd dropdownOptionSelected" value="">Any Sq. Ft.</div><div class="dropdownOption" value="250">250+</div><div class="dropdownOption dropdownOptionOdd" value="500">500+</div><div class="dropdownOption" value="1000">1000+</div><div class="dropdownOption dropdownOptionOdd" value="2500">2500+</div><div class="dropdownOption" value="5000">5000+</div><div class="dropdownOption dropdownOptionOdd" value="10000">10000+</div></div></div></div><div class="dropdownBox dropdownCustomizations dropdownPrice" id="generated_903" showing="false" style="top: -9999px; left: -9999px; display: block;"><div class="dropdownHeader"><div class="dropdownHeaderContainer"><div class="background">Min Price</div><input class="foreground" maxlength="10" tabindex="100" type="text"/></div></div><div class="dropdownOptionViewport"><div class="dropdownOptionContainer"><div class="dropdownOption dropdownOptionOdd" value="$10,000">$10,000</div><div class="dropdownOption" value="$20,000">$20,000</div><div class="dropdownOption dropdownOptionOdd" value="$30,000">$30,000</div><div class="dropdownOption" value="$50,000">$50,000</div><div class="dropdownOption dropdownOptionOdd" value="$75,000">$75,000</div><div class="dropdownOption" value="$100,000">$100,000</div><div class="dropdownOption dropdownOptionOdd" va ...

# %%
all = soup.find_all("div",{"class":"propertyRow"})
page_nr=soup.find_all("a",{"class":"Page"})[-1].text
print(page_nr)
# Out:
# 3

# %%
all
# Out:
# [<div class="propertyRow" id="propertyRowREN021201395" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/0-gateway-rock-springs-wy-82901-REN021201395';">
#  <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN021201395">
#  <div class="CenterLaneCard propertyCard">
#  <div class="CardThumb">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156419/1?lm=20151103T230938" src="./LCWYROCKSPRINGS1_files/1"/></a>
#  </div>
#  </div>
#  <h4 class="propPrice">
#
#
#              $725,000
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>
#  <div class="CardDetails">
#  <div class="primaryDetails">
#  <span class="propAddressCollapse" title="0 Gateway">0 Gateway</span>
#  <span class="propAddressCollapse">Rock Springs, WY 82901</span>
#  <input name="shortCurrency" type="hidden" value="$725K"/>
#  <input name="proplongitude" type="hidden" value="-109.248"/>
#  <input name="proplatitude" type="hidden" value="41.5842"/>
#  </div>
#  <div class="secondaryDetails">
#  <div class="infoLine1">
#  </div>
#  <div class="infoLine2">
#  </div>
#  </div>
#  <div class="secondaryHeader">
#           Courtesy Of All Broker Realty
#
#        </div>
#  </div>
#  </div>
#  <div class="CardActions">
#  <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395">
#  <span class="IconPropertyPhotos16"></span>
#
#        1
#        Image
#     </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="Hide">
#  <span class="IconActionHide16"></span><b>Hide</b>
#  </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN021201395', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
#  <span class="IconActionContact16"></span><b>Contact</b>
#  </a>
#  <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN021201395', '#propertyREN021201395');c21Helpers.stopEvent(event);" title="Remove Favorite">
#  <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#           </a>
#  <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN021201395', '#propertyREN021201395', '3yd-FCBRWY-20156419');c21Helpers.stopEvent(event);" title="Add to Favorites">
#  <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
#  </a>
#  </div>
#  <div class="hiddenListItem">
#  <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="0 Gateway, Rock Springs, WY 82901 | $725,000">
#  <span class="IconActionUnhide16"></span>
#  </a>
#  <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="0 Gateway, Rock Springs, WY 82901 | $725,000">
#        Unhide Property: 0 Gateway, Rock Springs, WY 82901 | $725,000
#     </a>
#  </div>
#  <div class="clear"></div>
#  </div>
#  <div class="propertyDetails">
#  <div class="invisibleFloat"></div>
#  <div class="propertyDetailPhotos" id="propertyRowREN021201395propertyDetailPhotos">
#  <div class="photoFlow last">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156419/1?lm=20151103T230938" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="propertyMLS">MLS#
#
#                          20156419
#
#                    </div>
#  </div>
#  <div class="propertyDescription" id="propertyRowREN021201395propertyDescription">
#  <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
#  <div class="propertyDescCollapse collapsed" expandlink="/property/0-gateway-rock-springs-wy-82901-REN021201395" id="propertyRowREN021201395propertyDescCollapse" style="display: block;"> This Location could be used for almost anything, close to Hospital, Residential, Great possibilities </div>
#  </div>
#  <div class="propertyFeatures" id="propertyRowREN021201395propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
#  </div></div></div>
#  </div>
#  </div>,
#  <div class="propertyRow" id="propertyRowC2123600598" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand C21 to view details'); document.location.href='/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598';">
#  <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyC2123600598">
#  <div class="CenterLaneCard propertyCard">
#  <div class="CardThumb">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598"><img class="lazyLoad" rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/tzb458q90brdmetfv72wmznb15i96" src="./LCWYROCKSPRINGS1_files/tzb458q90brdmetfv72wmznb15i96"/></a>
#  </div>
#  </div>
#  <h4 class="propPrice">
#
#
#              $452,900
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>
#  <div class="CardDetails">
#  <div class="primaryDetails">
#  <span class="propAddressCollapse" title="1003 Winchester Blvd.">1003 Winchester Blvd.</span>
#  <span class="propAddressCollapse">Rock Springs, WY 82901</span>
#  <input name="shortCurrency" type="hidden" value="$452K"/>
#  </div>
#  <div class="secondaryDetails">
#  <div class="infoLine1">
#  <span class="infoBed"><b>4</b> Beds</span>
#  </div>
#  <div class="infoLine2">
#  <span class="infoValueFullBath"><b>4</b> Full Baths</span>
#  </div>
#  </div>
#  <div class="secondaryHeader">
#           Listed By CENTURY 21 Rocky Mountain Realty
#
#        </div>
#  </div>
#  </div>
#  <div class="CardActions">
#  <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598">
#  <span class="IconPropertyPhotos16"></span>
#
#        7
#        Images
#     </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="Hide">
#  <span class="IconActionHide16"></span><b>Hide</b>
#  </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('C2123600598', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
#  <span class="IconActionContact16"></span><b>Contact</b>
#  </a>
#  <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('C2123600598', '#propertyC2123600598');c21Helpers.stopEvent(event);" title="Remove Favorite">
#  <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#           </a>
#  <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('C2123600598', '#propertyC2123600598', '9B9FB677-D8DE-4F7F-A074-4BDE356D7101');c21Helpers.stopEvent(event);" title="Add to Favorites">
#  <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
#  </a>
#  </div>
#  <div class="hiddenListItem">
#  <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900">
#  <span class="IconActionUnhide16"></span>
#  </a>
#  <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900">
#        Unhide Property: 1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900
#     </a>
#  </div>
#  <div class="clear"></div>
#  </div>
#  <div class="propertyDetails">
#  <div class="invisibleFloat"></div>
#  <div class="propertyDetailPhotos" id="propertyRowC2123600598propertyDetailPhotos">
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=0" title="WYO20152130"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/tzb458q90brdmetfv72wmznb15i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=1" title="WYO20152130A"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/g9a8gzjggb0vmpjvkb9am7enj2i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=2" title="WYO20152130B"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/vzsee1s7ssdb4c6rjw8ark33b1i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=3" title="WYO20152130E"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/5qj4qbrbe9s34vysd71a8x15z2i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=4" title="WYO20152130F"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/9wtxbdwh5g4x452nk7p5k57wt4i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=5" title="WYO20152130C"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/g3pf89v2zs7mm5pyjf4bx318p3i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow last">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=6" title="WYO20152130G"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/33d5vb5caqqtm12rdxmp39e9w5i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="propertyMLS">MLS#
#
#                          20152130
#
#                    </div>
#  </div>
#  <div class="propertyDescription" id="propertyRowC2123600598propertyDescription">
#  <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
#  <div class="propertyDescCollapse collapsed" expandlink="/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598" id="propertyRowC2123600598propertyDescCollapse" style="display: block;"> Beautiful new construction located on a corner lot near parks &amp; Family Rec Center. Get in early to be able to pick features. 4 bedrooms, 4 baths, 3 car garage, finished basement w/ built in media room, 2 fireplaces. Built in projector, surround sound, receivers &amp; specially painted screen wall <a href="http://web.archive.org/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598" style="white-space: nowrap;" title="in media room. 8 foot interior doors, TONS of closet space throughout the home. Bonus room upstairs. Energy efficient furnace &amp; A/C. Expected completion Mid June 2015. This is a MUST SEE new home, LOTS OF UPGRADES!  ">…Read More</a></div><span style="display: none">in media room. 8 foot interior doors, TONS of closet space throughout the home. Bonus room upstairs. Energy efficient furnace &amp; A/C. Expected completion Mid June 2015. This is a MUST SEE new home, LOTS OF UPGRADES!  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
#  </div>
#  <div class="propertyFeatures" id="propertyRowC2123600598propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Age: </span><span class="featureName">New Construction</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Double Oven, </span><span class="featureName">Garbage Disposal, </span><span class="featureName">Range / Oven, </span><span class="featureName">Refrigerator</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Basement: </span><span class="featureName">Finished</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Bath Features: </span><span class="featureName">Stall Shower and Tub, </span><span class="featureName">Tub and Shower</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Cooling: </span><span class="featureName">Central A/C</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior: </span><span class="featureName">Thermal Windows / Doors</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior Description: </span><span class="featureName">Other, </span><span class="featureName">Stone, </span><span class="featureName">Stucco</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Exterior Living Space: </span><span class="featureName">Deck</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fireplace Count: </span><span class="featureName">2 Fireplaces</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fireplace Description: </span><span class="featureName">Gas</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Flooring: </span><span class="featureName">Hardwood, </span><span class="featureName">Tile, </span><span class="featureName">Wall to Wall Carpet</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Garage Count: </span><span class="featureName">3 Car Garage</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Garage Description: </span><span class="featureName">Attached Garage</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Gas</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Interior: </span><span class="featureName">Walk-in Closet</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Lot Description: </span><span class="featureName">Corner</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Lot Size: </span><span class="featureName">0.21 Acres</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Road Type: </span><span class="featureName">City / Town Street</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof: </span><span class="featureName">Asphalt Shingle Roof</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Rooms: </span><span class="featureName">Media Room / Home Theater</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Sewer: </span><span class="featureName">City</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Style: </span><span class="featureName">Custom</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Water: </span><span class="featureName">City Water</span>
#  </div></div></div>
#  </div>
#  </div>,
#  <div class="propertyRow" id="propertyRowREN021194119" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/600-talladega-rock-springs-wy-82901-REN021194119';">
#  <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN021194119">
#  <div class="CenterLaneCard propertyCard">
#  <div class="CardThumb">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/1?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/1(1)"/></a>
#  </div>
#  </div>
#  <h4 class="propPrice">
#
#
#              $396,900
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>
#  <div class="CardDetails">
#  <div class="primaryDetails">
#  <span class="propAddressCollapse" title="600 Talladega">600 Talladega</span>
#  <span class="propAddressCollapse">Rock Springs, WY 82901</span>
#  <input name="shortCurrency" type="hidden" value="$396K"/>
#  <input name="proplongitude" type="hidden" value="-109.272"/>
#  <input name="proplatitude" type="hidden" value="41.5942"/>
#  </div>
#  <div class="secondaryDetails">
#  <div class="infoLine1">
#  <span class="infoBed"><b>5</b> Beds</span>
#  <span class="infoSqFt"><b>3,154</b> Sq. Ft</span>
#  </div>
#  <div class="infoLine2">
#  <span class="infoValueFullBath"><b>3</b> Full Baths</span>
#  </div>
#  </div>
#  <div class="secondaryHeader">
#           Courtesy Of All Broker Realty
#
#        </div>
#  </div>
#  </div>
#  <div class="CardActions">
#  <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119">
#  <span class="IconPropertyPhotos16"></span>
#
#        16
#        Images
#     </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="Hide">
#  <span class="IconActionHide16"></span><b>Hide</b>
#  </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN021194119', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
#  <span class="IconActionContact16"></span><b>Contact</b>
#  </a>
#  <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN021194119', '#propertyREN021194119');c21Helpers.stopEvent(event);" title="Remove Favorite">
#  <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#           </a>
#  <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN021194119', '#propertyREN021194119', '3yd-FCBRWY-20156389');c21Helpers.stopEvent(event);" title="Add to Favorites">
#  <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
#  </a>
#  </div>
#  <div class="hiddenListItem">
#  <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="600 Talladega, Rock Springs, WY 82901 | $396,900">
#  <span class="IconActionUnhide16"></span>
#  </a>
#  <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="600 Talladega, Rock Springs, WY 82901 | $396,900">
#        Unhide Property: 600 Talladega, Rock Springs, WY 82901 | $396,900
#     </a>
#  </div>
#  <div class="clear"></div>
#  </div>
#  <div class="propertyDetails">
#  <div class="invisibleFloat"></div>
#  <div class="propertyDetailPhotos" id="propertyRowREN021194119propertyDetailPhotos">
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/1?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/2?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/3?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/4?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/5?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/6?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/7?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/8?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/9?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=9" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/10?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=10" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/11?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=11" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/12?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow last">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=12" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/13?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=13" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/14?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="viewMorePhotosContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
#  </div>
#  </div>
#  <div class="propertyMLS">MLS#
#
#                          20156389
#
#                    </div>
#  </div>
#  <div class="propertyDescription" id="propertyRowREN021194119propertyDescription">
#  <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
#  <div class="propertyDescCollapse collapsed" expandlink="/property/600-talladega-rock-springs-wy-82901-REN021194119" id="propertyRowREN021194119propertyDescCollapse" style="display: block;"> First Built in 2009 and upgraded this year. Here it is 5/bedroom or 4/bedroom &amp; a office, 3 full baths, Family Room &amp; Down Stairs Bath has Heated floors, Newer Carpet Throughout, New Hardwood Floors, newer landscaping &amp; Fence, Freshly Painted, Security System, Spinkler System, New Furnace <a href="http://web.archive.org/property/600-talladega-rock-springs-wy-82901-REN021194119" style="white-space: nowrap;" title="with Central Air, R/V Area, and much more. Basement details: fully finished luxury man/woman cave of a basement. A MUST SEE! Wireless in-wall flat speaker surround sound system, Call Scott at All Broker Realty 307 870-5809  ">…Read More</a></div><span style="display: none">with Central Air, R/V Area, and much more. Basement details: fully finished luxury man/woman cave of a basement. A MUST SEE! Wireless in-wall flat speaker surround sound system, Call Scott at All Broker Realty 307 870-5809  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
#  </div>
#  <div class="propertyFeatures" id="propertyRowREN021194119propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Age: </span><span class="featureName">6-10 Years Old</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Amenities: </span><span class="featureName">Vaulted Ceiling, </span><span class="featureName">Basement</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Garbage Disposer, </span><span class="featureName">Microwave, </span><span class="featureName">Oven, </span><span class="featureName">Refrigerator</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Architecture Style: </span><span class="featureName">Ranch</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Cooling System: </span><span class="featureName">Central A/C</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior Type: </span><span class="featureName">Stone, </span><span class="featureName">Stucco</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Floor Covering: </span><span class="featureName">Carpet, </span><span class="featureName">Hardwood, </span><span class="featureName">Tile</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating Fuel: </span><span class="featureName">Natural Gas</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating System: </span><span class="featureName">Forced Air, </span><span class="featureName">Radiant Floor</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Parking Type: </span><span class="featureName">Garage - Attached</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Rooms: </span><span class="featureName">Basement, </span><span class="featureName">Bedroom, </span><span class="featureName">Full Bath</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">View Type: </span><span class="featureName">Mountain</span>
#  </div></div></div>
#  </div>
#  </div>,
#  <div class="propertyRow" id="propertyRowCBR24443941" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand CBR to view details'); document.location.href='/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941';">
#  <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyCBR24443941">
#  <div class="CenterLaneCard propertyCard">
#  <div class="CardThumb">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941"><img class="lazyLoad" rel="http://i.coldwellbanker.com/236i82/9dgcy5ej670qmryxm2j05tnwj1i82" src="./LCWYROCKSPRINGS1_files/9dgcy5ej670qmryxm2j05tnwj1i82"/></a>
#  </div>
#  </div>
#  <h4 class="propPrice">
#
#
#              $389,900
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>
#  <div class="CardDetails">
#  <div class="primaryDetails">
#  <span class="propAddressCollapse" title="3239 Spearhead Way">3239 Spearhead Way</span>
#  <span class="propAddressCollapse">Rock Springs, WY 82901</span>
#  <input name="shortCurrency" type="hidden" value="$389K"/>
#  </div>
#  <div class="secondaryDetails">
#  <div class="infoLine1">
#  <span class="infoBed"><b>4</b> Beds</span>
#  <span class="infoSqFt"><b>3,076</b> Sq. Ft</span>
#  </div>
#  <div class="infoLine2">
#  <span class="infoValueFullBath"><b>3</b> Full Baths</span>
#  <span class="infoValueHalfBath"><b>1</b> Half Bath</span>
#  </div>
#  </div>
#  <div class="secondaryHeader">
#           Courtesy Of Coldwell Banker Sweetwater Realty
#
#        </div>
#  </div>
#  </div>
#  <div class="CardActions">
#  <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941">
#  <span class="IconPropertyPhotos16"></span>
#
#        24
#        Images
#     </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="Hide">
#  <span class="IconActionHide16"></span><b>Hide</b>
#  </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('CBR24443941', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
#  <span class="IconActionContact16"></span><b>Contact</b>
#  </a>
#  <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('CBR24443941', '#propertyCBR24443941');c21Helpers.stopEvent(event);" title="Remove Favorite">
#  <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#           </a>
#  <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('CBR24443941', '#propertyCBR24443941', '9945CFA7-FB39-4EBD-BA66-D5C11A6B709C');c21Helpers.stopEvent(event);" title="Add to Favorites">
#  <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
#  </a>
#  </div>
#  <div class="hiddenListItem">
#  <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="3239 Spearhead Way, Rock Springs, WY 82901 | $389,900">
#  <span class="IconActionUnhide16"></span>
#  </a>
#  <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="3239 Spearhead Way, Rock Springs, WY 82901 | $389,900">
#        Unhide Property: 3239 Spearhead Way, Rock Springs, WY 82901 | $389,900
#     </a>
#  </div>
#  <div class="clear"></div>
#  </div>
#  <div class="propertyDetails">
#  <div class="invisibleFloat"></div>
#  <div class="propertyDetailPhotos" id="propertyRowCBR24443941propertyDetailPhotos">
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=0" title="Front View"><img rel="http://i.coldwellbanker.com/236i82/9dgcy5ej670qmryxm2j05tnwj1i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=1" title="Front Entry"><img rel="http://i.coldwellbanker.com/236i82/cpd5f6ddsmaemfa6tkke1bnfg6i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=2" title="Gas Fireplace in Family Room"><img rel="http://i.coldwellbanker.com/236i82/knkfcpynzznam6eq7pjq1e0j17i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=3" title="Family Room w/gas fireplace"><img rel="http://i.coldwellbanker.com/236i82/czzxf8mcft03mx6xxcgjgb2g82i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=4" title="Gas fireplace"><img rel="http://i.coldwellbanker.com/236i82/xsyfy0ca911a4yan4z4br0h185i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=5" title="Open Floor concept"><img rel="http://i.coldwellbanker.com/236i82/t8cdbnn2aj08mnyp7yamd88ay4i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=6" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/6z6qs126qm4444epas050c7gr0i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=7" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/afgqm80hm2nt4tajbh65q283p6i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=8" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/0qkby86r0th8mhe7n9gjq3jaz5i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=9" title="Bedroom"><img rel="http://i.coldwellbanker.com/236i82/y7nxazn16qc342ttp6v7g45yr3i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=10" title="Full Bath up"><img rel="http://i.coldwellbanker.com/236i82/m9y2jc7wq78e43ab473v4c01b3i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=11" title="Bedroom"><img rel="http://i.coldwellbanker.com/236i82/198sp1x3wzjp4s6f8x1rhxw406i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow last">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=12" title="Master Bedroom"><img rel="http://i.coldwellbanker.com/236i82/6d9ge7j7zr2g4qpp6m6qb0pxf5i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=13" title="Master Bedroom w/gas Fireplace"><img rel="http://i.coldwellbanker.com/236i82/54965nje6ar14ajh2jpqjcqc63i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="viewMorePhotosContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
#  </div>
#  </div>
#  <div class="propertyMLS">MLS#
#
#                          20160119
#
#                    </div>
#  </div>
#  <div class="propertyDescription" id="propertyRowCBR24443941propertyDescription">
#  <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
#  <div class="propertyDescCollapse collapsed" expandlink="/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" id="propertyRowCBR24443941propertyDescCollapse" style="display: block;"> Beautiful Custom built home on large corner lot. Home has nice open floor plan, Gorgeous kitchen w/ beautiful cabinets, granite counter-tops, hardwood floors. Property has 2 master suites, one up, one down. One features a gas fireplace between bedroom and master bath. Living room <a href="http://web.archive.org/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" style="white-space: nowrap;" title="has beautiful gas fireplace w/ hardwood floors. Home has two heating systems and two hot water heaters. Basement also has some framing and sheet rock done and has plumbing for another bath. This one is a must see. Contact Cristal Hohler for your private showing 307-389-0051.  ">…Read More</a></div><span style="display: none">has beautiful gas fireplace w/ hardwood floors. Home has two heating systems and two hot water heaters. Basement also has some framing and sheet rock done and has plumbing for another bath. This one is a must see. Contact Cristal Hohler for your private showing 307-389-0051.  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
#  </div>
#  <div class="propertyFeatures" id="propertyRowCBR24443941propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Age: </span><span class="featureName">1-5 Years Old</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Garbage Disposal, </span><span class="featureName">Microwave, </span><span class="featureName">Range / Oven, </span><span class="featureName">Refrigerator</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Area Amenities: </span><span class="featureName">Biking, </span><span class="featureName">Area Climbing, </span><span class="featureName">Area Hiking, </span><span class="featureName">Area Hunting</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Basement: </span><span class="featureName">Full</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Bath Features: </span><span class="featureName">Stall Shower and Tub, </span><span class="featureName">Tub and Shower, </span><span class="featureName">Jetted Tub, </span><span class="featureName">Jetted Tub</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Cooling: </span><span class="featureName">Central A/C</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Exterior: </span><span class="featureName">Sidewalk</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior Description: </span><span class="featureName">Stucco</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior Living Space: </span><span class="featureName">Patio</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fencing: </span><span class="featureName">Partially Fenced, </span><span class="featureName">Vinyl Fence</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fireplace Count: </span><span class="featureName">2 Fireplaces</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fireplace Description: </span><span class="featureName">Gas, </span><span class="featureName">2-Sided</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Flooring: </span><span class="featureName">Hardwood, </span><span class="featureName">Mixed, </span><span class="featureName">Tile</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Garage Count: </span><span class="featureName">2 Car Garage</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Garage Description: </span><span class="featureName">Attached Garage</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">General: </span><span class="featureName">Smoke Detector</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Gas</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Interior: </span><span class="featureName">Walk-in Closet, </span><span class="featureName">Vaulted Ceilings, </span><span class="featureName">Fireplace in Master BR, </span><span class="featureName">Blinds</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Kitchen Features: </span><span class="featureName">Granite Countertops, </span><span class="featureName">Gourmet Kitchen, </span><span class="featureName">Designer Kitchen</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Lot Description: </span><span class="featureName">New Development, </span><span class="featureName">Corner</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Lot Size: </span><span class="featureName">Under 1/2 Acre, </span><span class="featureName">0.23 Acres</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Pre-Wiring: </span><span class="featureName">Garage Door</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Road Type: </span><span class="featureName">City / Town Street</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof: </span><span class="featureName">Asphalt / Fiberglass</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Sewer: </span><span class="featureName">City</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Style: </span><span class="featureName">Post-War</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Water: </span><span class="featureName">City Water</span>
#  </div></div></div>
#  </div>
#  </div>,
# ...
#  </div>
#  <div class="propertyFeatures" id="propertyRowCBR24365478propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Age: </span><span class="featureName">41-50 Years Old</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Microwave, </span><span class="featureName">Range / Oven, </span><span class="featureName">Refrigerator</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Basement: </span><span class="featureName">Finished</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Bath Features: </span><span class="featureName">Stall Shower, </span><span class="featureName">Tub and Shower, </span><span class="featureName">Jetted Tub, </span><span class="featureName">Jetted Tub</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior: </span><span class="featureName">Sprinkler System, </span><span class="featureName">Sidewalk, </span><span class="featureName">Storage Shed, </span><span class="featureName">Thermal Windows / Doors</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior Description: </span><span class="featureName">Vinyl Siding</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Fencing: </span><span class="featureName">Fenced Yard, </span><span class="featureName">Wood Fence</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Flooring: </span><span class="featureName">Linoleum, </span><span class="featureName">Tile, </span><span class="featureName">Wall to Wall Carpet, </span><span class="featureName">Laminate</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Gas</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Kitchen Features: </span><span class="featureName">Breakfast Bar</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Lot Size: </span><span class="featureName">Under 1/2 Acre, </span><span class="featureName">0.14 Acres</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Road Type: </span><span class="featureName">City / Town Street</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof: </span><span class="featureName">Metal Roof</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Sewer: </span><span class="featureName">Public</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Style: </span><span class="featureName">Post-War</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Views: </span><span class="featureName">Mountain</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Water: </span><span class="featureName">City Water</span>
#  </div></div></div>
#  </div>
#  </div>,
#  <div class="propertyRow" id="propertyRowC2124279808" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand C21 to view details'); document.location.href='/property/4-minnies-lane-rock-springs-wy-82901-C2124279808';">
#  <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyC2124279808">
#  <div class="CenterLaneCard propertyCard">
#  <div class="CardThumb">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808"><img class="lazyLoad" rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/8n8ntj056vch4rp5960bkcgvp5i96" src="./LCWYROCKSPRINGS1_files/8n8ntj056vch4rp5960bkcgvp5i96"/></a>
#  </div>
#  </div>
#  <h4 class="propPrice">
#
#
#              $196,900
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>
#  <div class="CardDetails">
#  <div class="primaryDetails">
#  <span class="propAddressCollapse" title="4 Minnies Lane">4 Minnies Lane</span>
#  <span class="propAddressCollapse">Rock Springs, WY 82901</span>
#  <input name="shortCurrency" type="hidden" value="$196K"/>
#  </div>
#  <div class="secondaryDetails">
#  <div class="infoLine1">
#  <span class="infoBed"><b>3</b> Beds</span>
#  <span class="infoSqFt"><b>1,664</b> Sq. Ft</span>
#  </div>
#  <div class="infoLine2">
#  <span class="infoValueFullBath"><b>2</b> Full Baths</span>
#  </div>
#  </div>
#  <div class="secondaryHeader">
#           Listed By CENTURY 21 Rocky Mountain Realty
#
#        </div>
#  </div>
#  </div>
#  <div class="CardActions">
#  <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808">
#  <span class="IconPropertyPhotos16"></span>
#
#        7
#        Images
#     </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('C2124279808', '#propertyRowC2124279808');c21Helpers.stopEvent(event);" title="Hide">
#  <span class="IconActionHide16"></span><b>Hide</b>
#  </a>
#  <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('C2124279808', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
#  <span class="IconActionContact16"></span><b>Contact</b>
#  </a>
#  <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('C2124279808', '#propertyC2124279808');c21Helpers.stopEvent(event);" title="Remove Favorite">
#  <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#           </a>
#  <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('C2124279808', '#propertyC2124279808', '33C276E3-ED09-4BB7-9CEF-D1EA462B070C');c21Helpers.stopEvent(event);" title="Add to Favorites">
#  <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
#  </a>
#  </div>
#  <div class="hiddenListItem">
#  <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2124279808', '#propertyRowC2124279808');c21Helpers.stopEvent(event);" title="4 Minnies Lane, Rock Springs, WY 82901 | $196,900">
#  <span class="IconActionUnhide16"></span>
#  </a>
#  <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2124279808', '#propertyRowC2124279808');c21Helpers.stopEvent(event);" title="4 Minnies Lane, Rock Springs, WY 82901 | $196,900">
#        Unhide Property: 4 Minnies Lane, Rock Springs, WY 82901 | $196,900
#     </a>
#  </div>
#  <div class="clear"></div>
#  </div>
#  <div class="propertyDetails">
#  <div class="invisibleFloat"></div>
#  <div class="propertyDetailPhotos" id="propertyRowC2124279808propertyDetailPhotos">
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=0" title="RF3A0366_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/8n8ntj056vch4rp5960bkcgvp5i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=1" title="RF3A0351_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/2te2xdmr1n4hmg2ez6x39x3rd7i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=2" title="RF3A0357_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/1qnqv3w6pqfm4eevh1g0z87vb1i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=3" title="RF3A0358_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/y0akztecn3rxm369twyvncfm64i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=4" title="RF3A0359_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/g3vvaj2c63eamf66eb4awz8v41i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=5" title="RF3A0361_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/ajy96hz020y047jrptsw1r68b3i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="photoFlow last">
#  <div class="landscapeThumbContainer">
#  <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/4-minnies-lane-rock-springs-wy-82901-C2124279808?g=6" title="RF3A0362_view"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/yphyr9sw1mbf4kyb3bxs8xz1b0i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
#  </div>
#  </div>
#  <div class="propertyMLS">MLS#
#
#                          20156365
#
#                    </div>
#  </div>
#  <div class="propertyDescription" id="propertyRowC2124279808propertyDescription">
#  <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
#  <div class="propertyDescCollapse collapsed" expandlink="/property/4-minnies-lane-rock-springs-wy-82901-C2124279808" id="propertyRowC2124279808propertyDescCollapse" style="display: block;"> Located 55 miles from Rock Springs along WY-191 South, near Dutch John Utah, this property makes for peaceful rural living and would be excellent for a recreation home. A very well maintained 3 bedroom 2 bath modular home on 2 acres within 15 minutes of Flaming Gorge/Antelope Flats <a href="http://web.archive.org/property/4-minnies-lane-rock-springs-wy-82901-C2124279808" style="white-space: nowrap;" title="Boat Launch. The second acre has electric and its own well and could be developed into income property  ">…Read More</a></div><span style="display: none">Boat Launch. The second acre has electric and its own well and could be developed into income property  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
#  </div>
#  <div class="propertyFeatures" id="propertyRowC2124279808propertyFeatures">
#  <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
#  <span class="featureGroup">Amenities: </span><span class="featureName">Horse facilities</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Range / Oven</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Area Amenities: </span><span class="featureName">Boating, </span><span class="featureName">Outdoor Activities, </span><span class="featureName">Area Fishing, </span><span class="featureName">Area Hunting, </span><span class="featureName">Area Boat Dock, </span><span class="featureName">Area Boat Ramp</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Area Description: </span><span class="featureName">Country Living, </span><span class="featureName">Fishing, </span><span class="featureName">Hunting</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Bath Features: </span><span class="featureName">Tub and Shower</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Body of Water: </span><span class="featureName">Reservoir</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Cooling: </span><span class="featureName">No A/C</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Exterior: </span><span class="featureName">Storage Shed</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Exterior Description: </span><span class="featureName">Hardiboard Siding</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Flooring: </span><span class="featureName">Linoleum, </span><span class="featureName">Wall to Wall Carpet</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Garage Description: </span><span class="featureName">RV Parking, </span><span class="featureName">Attached Garage</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">General: </span><span class="featureName">Laundry Facilities, </span><span class="featureName">Smoke Detector, </span><span class="featureName">Storage Area</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Propane</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Interior: </span><span class="featureName">Walk-in Closet, </span><span class="featureName">Vaulted Ceilings, </span><span class="featureName">Blinds</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Kitchen Features: </span><span class="featureName">Eat-in Kitchen, </span><span class="featureName">Center Island</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Lot Description: </span><span class="featureName">Access Type - Road</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Lot Size: </span><span class="featureName">2.02 Acres</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Road Type: </span><span class="featureName">Private Road</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Roof: </span><span class="featureName">Asphalt / Fiberglass</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Special Market: </span><span class="featureName">Vacation / Second Home</span>
#  </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
#  <span class="featureGroup">Style: </span><span class="featureName">1 Level Ranch</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Views: </span><span class="featureName">Mountain</span>
#  </div><div class="columnGroup">
#  <span class="featureGroup">Zoning: </span><span class="featureName">Residential</span>
#  </div></div></div>
#  </div>
#  </div>]

# %%
len(all)
# Out:
# 10

# %%
all[0].find_all("h4",{"class":"propPrice"})
# Out:
# [<h4 class="propPrice">
#
#
#              $725,000
#
#
#
#        <span class="IconPropertyFavorite16"></span>
#  </h4>]

# %%
all[0].find("h4",{"class":"propPrice"})
# Out:
# <h4 class="propPrice">
#
#
#             $725,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>

# %%
all[0].find("h4",{"class":"propPrice"}).text
# Out:
# '\n\n\n            $725,000\n\n\n\n      \n'

# %%
all[0].find("h4",{"class":"propPrice"}).text.replace("\n","")
# Out:
# '            $725,000      '

# %%
all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
# Out:
# '$725,000'

# %%
for item in all:
    print(item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ",""))
    print(item.find_all("span",{"class":"propAddressCollapse"})[0].text)
    print(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    try:
        print(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        print("None")
    try:
        print(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        print("None")
    try:
        print(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        print("None")
    try:
        print(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        print("None")
    
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        #print(column_group)
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
            #print(feature_group.text,feature_name.text)
            if "Lot Size" in feature_group.text:
                print(feature_name.text)
    print(" ")
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4
# None
# 4
# None
# 0.21 Acres
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5
# 3,154
# 3
# None
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4
# 3,076
# 3
# 1
# Under 1/2 Acre,
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3
# 1,172
# 3
# None
# Under 1/2 Acre,
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4
# 1,932
# 2
# None
# 0.27 Acres
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4
# 1,676
# 3
# None
# Under 1/2 Acre,
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3
# 1,344
# 2
# None
# Under 1/2 Acre,
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3
# 1,920
# 2
# None
# Under 1/2 Acre,
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3
# 1,664
# 2
# None
# 2.02 Acres

# %%
l=[]
for item in all:
    d={}
    d["Address"]=item.find_all("span",{"class":"propAddressCollapse"})[0].text
    d["Locality"]=item.find_all("span",{"class":"propAddressCollapse"})[1].text
    d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
    try:
        d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
    except:
        d["Beds"]=None
    try:
        d["SquareFeet"]=item.find("span",{"class":"infoSqFt"}).find("b").text
    except:
        d["SquareFeet"]=None
    try:
        d["FullBath"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
    except:
        d["FullBath"]=None
    try:
        d["HalfBath"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
    except:
        d["HalfBath"]=None
    
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        #print(column_group)
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
            #print(feature_group.text,feature_name.text)
            if "Lot Size" in feature_group.text:
                d["LotSize"]=feature_name.text
    #print(" ")
    l.append(d)

# %%
l
# Out:
# [{'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000',
#   'Beds': None,
#   'SquareFeet': None,
#   'FullBath': None,
#   'HalfBath': None},
#  {'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$452,900',
#   'Beds': '4',
#   'SquareFeet': None,
#   'FullBath': '4',
#   'HalfBath': None,
#   'LotSize': '0.21 Acres'},
#  {'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900',
#   'Beds': '5',
#   'SquareFeet': '3,154',
#   'FullBath': '3',
#   'HalfBath': None},
#  {'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$389,900',
#   'Beds': '4',
#   'SquareFeet': '3,076',
#   'FullBath': '3',
#   'HalfBath': '1',
#   'LotSize': 'Under 1/2 Acre, '},
#  {'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$254,000',
#   'Beds': '3',
#   'SquareFeet': '1,172',
#   'FullBath': '3',
#   'HalfBath': None,
#   'LotSize': 'Under 1/2 Acre, '},
#  {'Address': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$252,900',
#   'Beds': '4',
#   'SquareFeet': '1,932',
#   'FullBath': '2',
#   'HalfBath': None,
#   'LotSize': '0.27 Acres'},
#  {'Address': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$210,000',
#   'Beds': '4',
#   'SquareFeet': '1,676',
#   'FullBath': '3',
#   'HalfBath': None,
#   'LotSize': 'Under 1/2 Acre, '},
#  {'Address': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$209,000',
#   'Beds': '3',
#   'SquareFeet': '1,344',
#   'FullBath': '2',
#   'HalfBath': None,
#   'LotSize': 'Under 1/2 Acre, '},
#  {'Address': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$199,900',
#   'Beds': '3',
#   'SquareFeet': '1,920',
#   'FullBath': '2',
#   'HalfBath': None,
#   'LotSize': 'Under 1/2 Acre, '},
#  {'Address': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$196,900',
#   'Beds': '3',
#   'SquareFeet': '1,664',
#   'FullBath': '2',
#   'HalfBath': None,
#   'LotSize': '2.02 Acres'}]

# %%
len(l)
# Out:
# 10

# %%
import pandas as pd
df = pd.DataFrame(l)

# %%
df
# Out:
#                  Address                Locality     Price  Beds SquareFeet  \
# 0              0 Gateway  Rock Springs, WY 82901  $725,000  None       None
# 1  1003 Winchester Blvd.  Rock Springs, WY 82901  $452,900     4       None
# 2          600 Talladega  Rock Springs, WY 82901  $396,900     5      3,154
# 3     3239 Spearhead Way  Rock Springs, WY 82901  $389,900     4      3,076
# 4     522 Emerald Street  Rock Springs, WY 82901  $254,000     3      1,172
# 5   1302 Veteran's Drive  Rock Springs, WY 82901  $252,900     4      1,932
# 6       1021 Cypress Cir  Rock Springs, WY 82901  $210,000     4      1,676
# 7         913 Madison Dr  Rock Springs, WY 82901  $209,000     3      1,344
# 8      1344 Teton Street  Rock Springs, WY 82901  $199,900     3      1,920
# 9         4 Minnies Lane  Rock Springs, WY 82901  $196,900     3      1,664
#
#   FullBath HalfBath           LotSize
# 0     None     None               NaN
# 1        4     None        0.21 Acres
# 2        3     None               NaN
# 3        3        1  Under 1/2 Acre,
# 4        3     None  Under 1/2 Acre,
# 5        2     None        0.27 Acres
# 6        3     None  Under 1/2 Acre,
# 7        2     None  Under 1/2 Acre,
# 8        2     None  Under 1/2 Acre,
# 9        2     None        2.02 Acres

# %%
df.to_csv("output.csv")

# %%
base_url= "http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,30,10):
    print(base_url+str(page)+".html")
    r=requests.get(base_url + str(page) + ".html",headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all = soup.find_all("div",{"class":"propertyRow"})
    print(all)
# Out:
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# [<div class="propertyRow" id="propertyRowREN021201395" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/0-gateway-rock-springs-wy-82901-REN021201395';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN021201395">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156419/1?lm=20151103T230938" src="./LCWYROCKSPRINGS1_files/1"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $725,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="0 Gateway">0 Gateway</span>
# <span class="propAddressCollapse">Rock Springs, WY 82901</span>
# <input name="shortCurrency" type="hidden" value="$725K"/>
# <input name="proplongitude" type="hidden" value="-109.248"/>
# <input name="proplatitude" type="hidden" value="41.5842"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of All Broker Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395">
# <span class="IconPropertyPhotos16"></span>
#
#       1
#       Image
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN021201395', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN021201395', '#propertyREN021201395');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN021201395', '#propertyREN021201395', '3yd-FCBRWY-20156419');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="0 Gateway, Rock Springs, WY 82901 | $725,000">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021201395', '#propertyRowREN021201395');c21Helpers.stopEvent(event);" title="0 Gateway, Rock Springs, WY 82901 | $725,000">
#       Unhide Property: 0 Gateway, Rock Springs, WY 82901 | $725,000
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN021201395propertyDetailPhotos">
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/0-gateway-rock-springs-wy-82901-REN021201395?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156419/1?lm=20151103T230938" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         20156419
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN021201395propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/0-gateway-rock-springs-wy-82901-REN021201395" id="propertyRowREN021201395propertyDescCollapse" style="display: block;"> This Location could be used for almost anything, close to Hospital, Residential, Great possibilities </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN021201395propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowC2123600598" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand C21 to view details'); document.location.href='/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyC2123600598">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598"><img class="lazyLoad" rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/tzb458q90brdmetfv72wmznb15i96" src="./LCWYROCKSPRINGS1_files/tzb458q90brdmetfv72wmznb15i96"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $452,900
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="1003 Winchester Blvd.">1003 Winchester Blvd.</span>
# <span class="propAddressCollapse">Rock Springs, WY 82901</span>
# <input name="shortCurrency" type="hidden" value="$452K"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>4</b> Beds</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>4</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Listed By CENTURY 21 Rocky Mountain Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598">
# <span class="IconPropertyPhotos16"></span>
#
#       7
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('C2123600598', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('C2123600598', '#propertyC2123600598');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('C2123600598', '#propertyC2123600598', '9B9FB677-D8DE-4F7F-A074-4BDE356D7101');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2123600598', '#propertyRowC2123600598');c21Helpers.stopEvent(event);" title="1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900">
#       Unhide Property: 1003 Winchester Blvd., Rock Springs, WY 82901 | $452,900
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowC2123600598propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=0" title="WYO20152130"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/tzb458q90brdmetfv72wmznb15i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=1" title="WYO20152130A"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/g9a8gzjggb0vmpjvkb9am7enj2i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=2" title="WYO20152130B"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/vzsee1s7ssdb4c6rjw8ark33b1i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=3" title="WYO20152130E"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/5qj4qbrbe9s34vysd71a8x15z2i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=4" title="WYO20152130F"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/9wtxbdwh5g4x452nk7p5k57wt4i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=5" title="WYO20152130C"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/g3pf89v2zs7mm5pyjf4bx318p3i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598?g=6" title="WYO20152130G"><img rel="http://www.century21.com/c21/photo/320x240/i.c21.com/236i96/33d5vb5caqqtm12rdxmp39e9w5i96" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         20152130
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowC2123600598propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598" id="propertyRowC2123600598propertyDescCollapse" style="display: block;"> Beautiful new construction located on a corner lot near parks &amp; Family Rec Center. Get in early to be able to pick features. 4 bedrooms, 4 baths, 3 car garage, finished basement w/ built in media room, 2 fireplaces. Built in projector, surround sound, receivers &amp; specially painted screen wall <a href="http://web.archive.org/property/1003-winchester-blvd--rock-springs-wy-82901-C2123600598" style="white-space: nowrap;" title="in media room. 8 foot interior doors, TONS of closet space throughout the home. Bonus room upstairs. Energy efficient furnace &amp; A/C. Expected completion Mid June 2015. This is a MUST SEE new home, LOTS OF UPGRADES!  ">…Read More</a></div><span style="display: none">in media room. 8 foot interior doors, TONS of closet space throughout the home. Bonus room upstairs. Energy efficient furnace &amp; A/C. Expected completion Mid June 2015. This is a MUST SEE new home, LOTS OF UPGRADES!  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
# </div>
# <div class="propertyFeatures" id="propertyRowC2123600598propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Age: </span><span class="featureName">New Construction</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Double Oven, </span><span class="featureName">Garbage Disposal, </span><span class="featureName">Range / Oven, </span><span class="featureName">Refrigerator</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Basement: </span><span class="featureName">Finished</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Bath Features: </span><span class="featureName">Stall Shower and Tub, </span><span class="featureName">Tub and Shower</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Cooling: </span><span class="featureName">Central A/C</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior: </span><span class="featureName">Thermal Windows / Doors</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior Description: </span><span class="featureName">Other, </span><span class="featureName">Stone, </span><span class="featureName">Stucco</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Exterior Living Space: </span><span class="featureName">Deck</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace Count: </span><span class="featureName">2 Fireplaces</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace Description: </span><span class="featureName">Gas</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Flooring: </span><span class="featureName">Hardwood, </span><span class="featureName">Tile, </span><span class="featureName">Wall to Wall Carpet</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Garage Count: </span><span class="featureName">3 Car Garage</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Garage Description: </span><span class="featureName">Attached Garage</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Gas</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Interior: </span><span class="featureName">Walk-in Closet</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Description: </span><span class="featureName">Corner</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">0.21 Acres</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Road Type: </span><span class="featureName">City / Town Street</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof: </span><span class="featureName">Asphalt Shingle Roof</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Rooms: </span><span class="featureName">Media Room / Home Theater</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Sewer: </span><span class="featureName">City</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Style: </span><span class="featureName">Custom</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Water: </span><span class="featureName">City Water</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowREN021194119" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/600-talladega-rock-springs-wy-82901-REN021194119';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN021194119">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/1?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/1(1)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $396,900
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="600 Talladega">600 Talladega</span>
# <span class="propAddressCollapse">Rock Springs, WY 82901</span>
# <input name="shortCurrency" type="hidden" value="$396K"/>
# <input name="proplongitude" type="hidden" value="-109.272"/>
# <input name="proplatitude" type="hidden" value="41.5942"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>5</b> Beds</span>
# <span class="infoSqFt"><b>3,154</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>3</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of All Broker Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119">
# <span class="IconPropertyPhotos16"></span>
#
#       16
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN021194119', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN021194119', '#propertyREN021194119');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN021194119', '#propertyREN021194119', '3yd-FCBRWY-20156389');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="600 Talladega, Rock Springs, WY 82901 | $396,900">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN021194119', '#propertyRowREN021194119');c21Helpers.stopEvent(event);" title="600 Talladega, Rock Springs, WY 82901 | $396,900">
#       Unhide Property: 600 Talladega, Rock Springs, WY 82901 | $396,900
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN021194119propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/1?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/2?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/3?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/4?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/5?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/6?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/7?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/8?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/9?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=9" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/10?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=10" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/11?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=11" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/12?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=12" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/13?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119?g=13" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/FCBRWY/20156389/14?lm=20151103T230935" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="viewMorePhotosContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/600-talladega-rock-springs-wy-82901-REN021194119" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         20156389
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN021194119propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/600-talladega-rock-springs-wy-82901-REN021194119" id="propertyRowREN021194119propertyDescCollapse" style="display: block;"> First Built in 2009 and upgraded this year. Here it is 5/bedroom or 4/bedroom &amp; a office, 3 full baths, Family Room &amp; Down Stairs Bath has Heated floors, Newer Carpet Throughout, New Hardwood Floors, newer landscaping &amp; Fence, Freshly Painted, Security System, Spinkler System, New Furnace <a href="http://web.archive.org/property/600-talladega-rock-springs-wy-82901-REN021194119" style="white-space: nowrap;" title="with Central Air, R/V Area, and much more. Basement details: fully finished luxury man/woman cave of a basement. A MUST SEE! Wireless in-wall flat speaker surround sound system, Call Scott at All Broker Realty 307 870-5809  ">…Read More</a></div><span style="display: none">with Central Air, R/V Area, and much more. Basement details: fully finished luxury man/woman cave of a basement. A MUST SEE! Wireless in-wall flat speaker surround sound system, Call Scott at All Broker Realty 307 870-5809  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
# </div>
# <div class="propertyFeatures" id="propertyRowREN021194119propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Age: </span><span class="featureName">6-10 Years Old</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Amenities: </span><span class="featureName">Vaulted Ceiling, </span><span class="featureName">Basement</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Garbage Disposer, </span><span class="featureName">Microwave, </span><span class="featureName">Oven, </span><span class="featureName">Refrigerator</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Ranch</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Cooling System: </span><span class="featureName">Central A/C</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior Type: </span><span class="featureName">Stone, </span><span class="featureName">Stucco</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Floor Covering: </span><span class="featureName">Carpet, </span><span class="featureName">Hardwood, </span><span class="featureName">Tile</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating Fuel: </span><span class="featureName">Natural Gas</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating System: </span><span class="featureName">Forced Air, </span><span class="featureName">Radiant Floor</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Parking Type: </span><span class="featureName">Garage - Attached</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Rooms: </span><span class="featureName">Basement, </span><span class="featureName">Bedroom, </span><span class="featureName">Full Bath</span>
# </div><div class="columnGroup">
# <span class="featureGroup">View Type: </span><span class="featureName">Mountain</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowCBR24443941" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand CBR to view details'); document.location.href='/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyCBR24443941">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941"><img class="lazyLoad" rel="http://i.coldwellbanker.com/236i82/9dgcy5ej670qmryxm2j05tnwj1i82" src="./LCWYROCKSPRINGS1_files/9dgcy5ej670qmryxm2j05tnwj1i82"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $389,900
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="3239 Spearhead Way">3239 Spearhead Way</span>
# <span class="propAddressCollapse">Rock Springs, WY 82901</span>
# <input name="shortCurrency" type="hidden" value="$389K"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>4</b> Beds</span>
# <span class="infoSqFt"><b>3,076</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>3</b> Full Baths</span>
# <span class="infoValueHalfBath"><b>1</b> Half Bath</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Coldwell Banker Sweetwater Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941">
# <span class="IconPropertyPhotos16"></span>
#
#       24
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('CBR24443941', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('CBR24443941', '#propertyCBR24443941');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('CBR24443941', '#propertyCBR24443941', '9945CFA7-FB39-4EBD-BA66-D5C11A6B709C');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="3239 Spearhead Way, Rock Springs, WY 82901 | $389,900">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR24443941', '#propertyRowCBR24443941');c21Helpers.stopEvent(event);" title="3239 Spearhead Way, Rock Springs, WY 82901 | $389,900">
#       Unhide Property: 3239 Spearhead Way, Rock Springs, WY 82901 | $389,900
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowCBR24443941propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=0" title="Front View"><img rel="http://i.coldwellbanker.com/236i82/9dgcy5ej670qmryxm2j05tnwj1i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=1" title="Front Entry"><img rel="http://i.coldwellbanker.com/236i82/cpd5f6ddsmaemfa6tkke1bnfg6i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=2" title="Gas Fireplace in Family Room"><img rel="http://i.coldwellbanker.com/236i82/knkfcpynzznam6eq7pjq1e0j17i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=3" title="Family Room w/gas fireplace"><img rel="http://i.coldwellbanker.com/236i82/czzxf8mcft03mx6xxcgjgb2g82i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=4" title="Gas fireplace"><img rel="http://i.coldwellbanker.com/236i82/xsyfy0ca911a4yan4z4br0h185i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=5" title="Open Floor concept"><img rel="http://i.coldwellbanker.com/236i82/t8cdbnn2aj08mnyp7yamd88ay4i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=6" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/6z6qs126qm4444epas050c7gr0i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=7" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/afgqm80hm2nt4tajbh65q283p6i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=8" title="Kitchen"><img rel="http://i.coldwellbanker.com/236i82/0qkby86r0th8mhe7n9gjq3jaz5i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=9" title="Bedroom"><img rel="http://i.coldwellbanker.com/236i82/y7nxazn16qc342ttp6v7g45yr3i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=10" title="Full Bath up"><img rel="http://i.coldwellbanker.com/236i82/m9y2jc7wq78e43ab473v4c01b3i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=11" title="Bedroom"><img rel="http://i.coldwellbanker.com/236i82/198sp1x3wzjp4s6f8x1rhxw406i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=12" title="Master Bedroom"><img rel="http://i.coldwellbanker.com/236i82/6d9ge7j7zr2g4qpp6m6qb0pxf5i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941?g=13" title="Master Bedroom w/gas Fireplace"><img rel="http://i.coldwellbanker.com/236i82/54965nje6ar14ajh2jpqjcqc63i82" src="./LCWYROCKSPRINGS1_files/loadingimage39x30.png"/></a>
# </div>
# <div class="viewMorePhotosContainer">
# <a href="http://web.archive.org/web/20160127020422/http://www.century21.com/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         20160119
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowCBR24443941propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" id="propertyRowCBR24443941propertyDescCollapse" style="display: block;"> Beautiful Custom built home on large corner lot. Home has nice open floor plan, Gorgeous kitchen w/ beautiful cabinets, granite counter-tops, hardwood floors. Property has 2 master suites, one up, one down. One features a gas fireplace between bedroom and master bath. Living room <a href="http://web.archive.org/property/3239-spearhead-way-rock-springs-wy-82901-CBR24443941" style="white-space: nowrap;" title="has beautiful gas fireplace w/ hardwood floors. Home has two heating systems and two hot water heaters. Basement also has some framing and sheet rock done and has plumbing for another bath. This one is a must see. Contact Cristal Hohler for your private showing 307-389-0051.  ">…Read More</a></div><span style="display: none">has beautiful gas fireplace w/ hardwood floors. Home has two heating systems and two hot water heaters. Basement also has some framing and sheet rock done and has plumbing for another bath. This one is a must see. Contact Cristal Hohler for your private showing 307-389-0051.  <a href="javascript: void(0)" style="white-space: nowrap;">&lt; less</a></span>
# </div>
# <div class="propertyFeatures" id="propertyRowCBR24443941propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Age: </span><span class="featureName">1-5 Years Old</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Garbage Disposal, </span><span class="featureName">Microwave, </span><span class="featureName">Range / Oven, </span><span class="featureName">Refrigerator</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Area Amenities: </span><span class="featureName">Biking, </span><span class="featureName">Area Climbing, </span><span class="featureName">Area Hiking, </span><span class="featureName">Area Hunting</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Basement: </span><span class="featureName">Full</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Bath Features: </span><span class="featureName">Stall Shower and Tub, </span><span class="featureName">Tub and Shower, </span><span class="featureName">Jetted Tub, </span><span class="featureName">Jetted Tub</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Cooling: </span><span class="featureName">Central A/C</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Exterior: </span><span class="featureName">Sidewalk</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior Description: </span><span class="featureName">Stucco</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior Living Space: </span><span class="featureName">Patio</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fencing: </span><span class="featureName">Partially Fenced, </span><span class="featureName">Vinyl Fence</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace Count: </span><span class="featureName">2 Fireplaces</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace Description: </span><span class="featureName">Gas, </span><span class="featureName">2-Sided</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Flooring: </span><span class="featureName">Hardwood, </span><span class="featureName">Mixed, </span><span class="featureName">Tile</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Garage Count: </span><span class="featureName">2 Car Garage</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Garage Description: </span><span class="featureName">Attached Garage</span>
# </div><div class="columnGroup">
# <span class="featureGroup">General: </span><span class="featureName">Smoke Detector</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Gas</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating Type: </span><span class="featureName">Forced Air</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Interior: </span><span class="featureName">Walk-in Closet, </span><span class="featureName">Vaulted Ceilings, </span><span class="featureName">Fireplace in Master BR, </span><span class="featureName">Blinds</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Kitchen Features: </span><span class="featureName">Granite Countertops, </span><span class="featureName">Gourmet Kitchen, </span><span class="featureName">Designer Kitchen</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Description: </span><span class="featureName">New Development, </span><span class="featureName">Corner</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">Under 1/2 Acre, </span><span class="featureName">0.23 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Pre-Wiring: </span><span class="featureName">Garage Door</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Road Type: </span><span class="featureName">City / Town Street</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof: </span><span class="featureName">Asphalt / Fiberglass</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Sewer: </span><span class="featureName">City</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Style: </span><span class="featureName">Post-War</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Water: </span><span class="featureName">City Water</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowCBR23944249" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand CBR to view details'); document.location.href='/property/522-emerald-street-rock-springs-wy-82901-CBR23944249';">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyCBR23944249">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# ...
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN007584333">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/0?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/0(11)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $28,995
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="19350 E SAGUARO Drive">19350 E SAGUARO Drive</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$28K"/>
# <input name="proplongitude" type="hidden" value="-112.144819"/>
# <input name="proplatitude" type="hidden" value="34.073355"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Courtney Valleywide Properties
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333">
# <span class="IconPropertyPhotos16"></span>
#
#       6
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN007584333', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN007584333', '#propertyREN007584333');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN007584333', '#propertyREN007584333');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995">
#       Unhide Property: 19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN007584333propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/0?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/0(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/2?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/2(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/3?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/3(11)"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/4?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/4(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/5?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/5(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/6?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/6(11)"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4848089
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN007584333propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333" id="propertyRowREN007584333propertyDescCollapse"> This cul-de-sac lot is waiting for your site built or manufactured home! Great views of the surrounding hills and mountains. Level lot with utilities to property line. Paved road. The adjacent approx. 1/2 acre lot is also available for same price. </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN007584333propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">0.73 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowREN004930163" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN004930163">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/0?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/0(12)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $15,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="20650 E Amethyst Place">20650 E Amethyst Place</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$15K"/>
# <input name="proplongitude" type="hidden" value="-112.122808"/>
# <input name="proplatitude" type="hidden" value="34.075862"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Realty One Group
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163">
# <span class="IconPropertyPhotos16"></span>
#
#       9
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN004930163', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN004930163', '#propertyREN004930163');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN004930163', '#propertyREN004930163');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000">
#       Unhide Property: 20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN004930163propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/0?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/0(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/2?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/2(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/3?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/3(12)"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/4?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/4(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/5?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/5(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/6?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/6(12)"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/7?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/7(10)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/8?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/8(8)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/9?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/9(8)"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4749944
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN004930163propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163" id="propertyRowREN004930163propertyDescCollapse"> Great Views on this corner lot. Small town living and only 12 mins to Anthem. Lots of vegetation. </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN004930163propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">0.31 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div></div></div>
# </div>
# </div>]

# %%
l=[]
base_url= "http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_nr)*10,10):
    print(base_url+str(page)+".html")
    r=requests.get(base_url + str(page) + ".html",headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all = soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class":"propAddressCollapse"})[0].text
        d["Locality"]=item.find_all("span",{"class":"propAddressCollapse"})[1].text
        d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
        except:
            d["Beds"]=None
        try:
            d["SquareFeet"]=item.find("span",{"class":"infoSqFt"}).find("b").text
        except:
            d["SquareFeet"]=None
        try:
            d["FullBath"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
        except:
            d["FullBath"]=None
        try:
            d["HalfBath"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
        except:
            d["HalfBath"]=None

        for column_group in item.find_all("div",{"class":"columnGroup"}):
            #print(column_group)
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                #print(feature_group.text,feature_name.text)
                if "Lot Size" in feature_group.text:
                    d["LotSize"]=feature_name.text
        #print(" ")
        l.append(d)
# Out:
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
import pandas as pd
property_data = pd.DataFrame(l)

# %%
property_data
# Out:
#                           Address                     Locality       Price  \
# 0                       0 Gateway       Rock Springs, WY 82901    $725,000
# 1           1003 Winchester Blvd.       Rock Springs, WY 82901    $452,900
# 2                   600 Talladega       Rock Springs, WY 82901    $396,900
# 3              3239 Spearhead Way       Rock Springs, WY 82901    $389,900
# 4              522 Emerald Street       Rock Springs, WY 82901    $254,000
# 5            1302 Veteran's Drive       Rock Springs, WY 82901    $252,900
# 6                1021 Cypress Cir       Rock Springs, WY 82901    $210,000
# 7                  913 Madison Dr       Rock Springs, WY 82901    $209,000
# 8               1344 Teton Street       Rock Springs, WY 82901    $199,900
# 9                  4 Minnies Lane       Rock Springs, WY 82901    $196,900
# 10                  9339 Sd 26900        Rocksprings, TX 78880  $1,700,000
# 11               RR674P13 Hwy 377        Rocksprings, TX 78880  $1,100,000
# 12                       0 Hwy 41        Rocksprings, TX 78880  $1,080,000
# 13                  9339 Sd 26900        Rocksprings, TX 78880    $908,350
# 14                  CR450 Hwy 377        Rocksprings, TX 78880    $905,000
# 15                  Cr 240 Cr 240        Rocksprings, TX 78880    $695,000
# 16                  RR674 Hwy 377        Rocksprings, TX 78880    $605,000
# 17                 9770a Sd 26900        Rocksprings, TX 78880    $559,805
# 18                  Lot17 CR 2630        Rocksprings, TX 78880    $504,000
# 19                 Tr12,16 CR 520        Rocksprings, TX 78880    $410,000
# 20   32575 S Shadow Mountain Road  Black Canyon City, AZ 85324    $299,900
# 21        32750 S Shangrila Drive  Black Canyon City, AZ 85324    $167,500
# 22      0000 Black Canyon Highway  Black Canyon City, AZ 85324    $150,000
# 23           34775 S CHOLLA Drive  Black Canyon City, AZ 85324    $129,500
# 24      33403 S. HA-WA-SI TERRACE  BLACK CANYON CITY, AZ 85324    $129,000
# 25          34263 S Bertha Street  Black Canyon City, AZ 85324     $80,000
# 26            33160 S Canyon Road  Black Canyon City, AZ 85324     $77,900
# 27        19421 E Todd Evans Road  Black Canyon City, AZ 85324     $70,500
# 28             18688 E AGUA Vista  Black Canyon City, AZ 85324     $70,000
# 29  50600 N Old Black Canyon Road  Black Canyon City, AZ 85324     $67,500
# 30      20101 E SQUAW VALLEY Road  Black Canyon City, AZ 85324     $54,900
# 31            33259 S Canyon Road  Black Canyon City, AZ 85324     $45,600
# 32          34558 S ROADRUNNER RD  Black Canyon City, AZ 85324     $40,000
# 33       19260 E Scenic Loop Road  Black Canyon City, AZ 85324     $30,000
# 34           19000 E MAREN Avenue  Black Canyon City, AZ 85324     $29,000
# 35          19350 E SAGUARO Drive  Black Canyon City, AZ 85324     $28,995
# 36         20650 E Amethyst Place  Black Canyon City, AZ 85324     $15,000
#
#     Beds SquareFeet FullBath HalfBath           LotSize
# 0   None       None     None     None               NaN
# 1      4       None        4     None        0.21 Acres
# 2      5      3,154        3     None               NaN
# 3      4      3,076        3        1  Under 1/2 Acre,
# 4      3      1,172        3     None  Under 1/2 Acre,
# 5      4      1,932        2     None        0.27 Acres
# 6      4      1,676        3     None  Under 1/2 Acre,
# 7      3      1,344        2     None  Under 1/2 Acre,
# 8      3      1,920        2     None  Under 1/2 Acre,
# 9      3      1,664        2     None        2.02 Acres
# 10  None      2,560     None     None               NaN
# 11  None      2,000     None     None               NaN
# 12  None       None     None     None               NaN
# 13  None      2,560     None     None               NaN
# 14  None       None     None     None               NaN
# 15  None      1,398     None     None               NaN
# 16  None      1,738     None     None               NaN
# 17  None      1,080     None     None               NaN
# 18  None       None     None     None               NaN
# 19  None       None     None     None               NaN
# 20     3      2,318        2     None               NaN
# 21     3      2,120        2     None               NaN
# 22  None       None     None     None           5 Acres
# 23     3      1,220        2     None               NaN
# 24     4      2,000        2     None               NaN
# 25     5      2,260        2     None               NaN
# 26     3      1,248        2     None               NaN
# 27     3      1,404        2     None               NaN
# 28  None       None     None     None         0.7 Acres
# 29  None       None     None     None           3 Acres
# 30  None       None     None     None               NaN
# 31     3      1,056        1     None               NaN
# 32     2        784        1     None    Under 1/2 Acre
# 33  None       None     None     None        2.35 Acres
# 34  None       None     None     None        2.05 Acres
# 35  None       None     None     None        0.73 Acres
# 36  None       None     None     None        0.31 Acres

# %%
property_data.to_csv("data.csv")
