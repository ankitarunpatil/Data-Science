# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
plt.imshow(X_train_full[1])

# %%
class_names = ["T-shirt/top","Trouser","Pullover","Dress","Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# # Data Reshape

# %%
# Height, width and channels. Hence, 3 parameters i.e 3D image 28*28*1 ---- 1 is for channel
X_train_full = X_train_full.reshape((60000,28,28,1))
X_test = X_test.reshape((10000,28,28,1))

# %% [markdown]
# # Normalization

# %%
X_train_n = X_train_full / 255
X_test_n = X_test / 255

# %% [markdown]
# # Splitting the data into train/ validation/ test

# %%
X_valid, X_train = X_train_n[:5000], X_train_n[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test_n

# %% [markdown]
# # Creating model architecture

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Architecture

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters= 32, kernel_size= (3,3), strides = 1, padding = 'valid', activation = 'relu', input_shape=(28,28,1)))
model.add(keras.layers.MaxPooling2D((2,2)))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(300,activation="relu"))
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dense(10,activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               1622700
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 1,654,130
# Trainable params: 1,654,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
             optimizer = "sgd",
             metrics=["accuracy"])

# %%
model_history = model.fit(X_train, y_train,epochs = 30,batch_size=64, validation_data=(X_valid, y_valid))
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/30
# 55000/55000 [==============================] - 15s 265us/sample - loss: 0.4443 - accuracy: 0.8399 - val_loss: 0.4427 - val_accuracy: 0.8386
# Epoch 2/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.4163 - accuracy: 0.8504 - val_loss: 0.4145 - val_accuracy: 0.8518
# Epoch 3/30
# 55000/55000 [==============================] - 15s 270us/sample - loss: 0.3951 - accuracy: 0.8581 - val_loss: 0.4024 - val_accuracy: 0.8534
# Epoch 4/30
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.3771 - accuracy: 0.8646 - val_loss: 0.3621 - val_accuracy: 0.8728
# Epoch 5/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.3622 - accuracy: 0.8698 - val_loss: 0.4230 - val_accuracy: 0.8426
# Epoch 6/30
# 55000/55000 [==============================] - 15s 270us/sample - loss: 0.3496 - accuracy: 0.8734 - val_loss: 0.3655 - val_accuracy: 0.8710
# Epoch 7/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.3390 - accuracy: 0.8770 - val_loss: 0.3680 - val_accuracy: 0.8720
# Epoch 8/30
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.3275 - accuracy: 0.8813 - val_loss: 0.3547 - val_accuracy: 0.8736
# Epoch 9/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.3188 - accuracy: 0.8840 - val_loss: 0.3517 - val_accuracy: 0.8722
# Epoch 10/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.3096 - accuracy: 0.8872 - val_loss: 0.4172 - val_accuracy: 0.8492
# Epoch 11/30
# 55000/55000 [==============================] - 15s 271us/sample - loss: 0.3032 - accuracy: 0.8882 - val_loss: 0.3369 - val_accuracy: 0.8766
# Epoch 12/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2964 - accuracy: 0.8926 - val_loss: 0.3328 - val_accuracy: 0.8812
# Epoch 13/30
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2887 - accuracy: 0.8935 - val_loss: 0.3025 - val_accuracy: 0.8938
# Epoch 14/30
# 55000/55000 [==============================] - 15s 277us/sample - loss: 0.2824 - accuracy: 0.8967 - val_loss: 0.3299 - val_accuracy: 0.8788
# Epoch 15/30
# 55000/55000 [==============================] - 15s 270us/sample - loss: 0.2767 - accuracy: 0.8987 - val_loss: 0.3289 - val_accuracy: 0.8830
# Epoch 16/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2712 - accuracy: 0.8993 - val_loss: 0.3145 - val_accuracy: 0.8862
# Epoch 17/30
# 55000/55000 [==============================] - 15s 277us/sample - loss: 0.2647 - accuracy: 0.9024 - val_loss: 0.3064 - val_accuracy: 0.8922
# Epoch 18/30
# 55000/55000 [==============================] - 15s 265us/sample - loss: 0.2597 - accuracy: 0.9045 - val_loss: 0.3010 - val_accuracy: 0.8920
# Epoch 19/30
# 55000/55000 [==============================] - 15s 266us/sample - loss: 0.2540 - accuracy: 0.9057 - val_loss: 0.4266 - val_accuracy: 0.8484
# Epoch 20/30
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2500 - accuracy: 0.9081 - val_loss: 0.2795 - val_accuracy: 0.8962
# Epoch 21/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2445 - accuracy: 0.9100 - val_loss: 0.2922 - val_accuracy: 0.8932
# Epoch 22/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2394 - accuracy: 0.9118 - val_loss: 0.3221 - val_accuracy: 0.8826
# Epoch 23/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2368 - accuracy: 0.9120 - val_loss: 0.2840 - val_accuracy: 0.8968
# Epoch 24/30
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.2299 - accuracy: 0.9153 - val_loss: 0.2743 - val_accuracy: 0.9028
# Epoch 25/30
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2263 - accuracy: 0.9159 - val_loss: 0.2699 - val_accuracy: 0.9006
# Epoch 26/30
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.2226 - accuracy: 0.9184 - val_loss: 0.2901 - val_accuracy: 0.8942
# Epoch 27/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.2175 - accuracy: 0.9199 - val_loss: 0.2683 - val_accuracy: 0.9016
# Epoch 28/30
# 55000/55000 [==============================] - 15s 277us/sample - loss: 0.2143 - accuracy: 0.9212 - val_loss: 0.2778 - val_accuracy: 0.8982
# Epoch 29/30
# 55000/55000 [==============================] - 15s 270us/sample - loss: 0.2097 - accuracy: 0.9225 - val_loss: 0.2761 - val_accuracy: 0.9026
# Epoch 30/30
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.2051 - accuracy: 0.9234 - val_loss: 0.3024 - val_accuracy: 0.8884

# %%
import pandas as pd
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
ev = model.evaluate(X_test_n,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
ev
# Out:
# [0.32112663024663923, 0.8842]

# %%
X_new = X_test[:3]

# %%
y_pred = model.predict_classes(X_new)
y_pred
# Out:
# array([9, 2, 1], dtype=int64)

# %%
y_test[:3]
# Out:
# array([9, 2, 1], dtype=uint8)

# %%
print(plt.imshow(X_test[0].reshape((28,28))))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
keras.backend.clear_session
# Out:
# <function tensorflow.python.keras.backend.clear_session()>

# %%
del model
